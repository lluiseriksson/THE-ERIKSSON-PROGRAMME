# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = 'https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/50b329574f54683304dfc6570536c46a32de104e/scripts/colab_c6d_step3_localized_precision_validation.py'
RUNNER_SHA256 = 'fca9eaa835e4bb2d771fa4cdfac8fe9d2e6df0f973aa7b4a07e5280ee0aa7d67'
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    print("RUNTIME_RETAINED_FOR_EVIDENCE=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq222CutoffSupportInteractionAudit.lean:8:0: 'YangMills.RG.CMP116Eq214FiniteGaussianData.ae_norm_innerIntegrand_le_exp_residual_sub_cardPenalty_mul_realGaussian_of_ae_cutoffSupport' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq222CutoffSupportInteractionAudit.lean:9:0: 'YangMills.RG.CMP116Eq214FiniteGaussianData.norm_innerIntegral_le_exp_residual_sub_cardPenalty_mul_eq224Majorant_of_ae_cutoffSupport' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10250/10320] Built YangMills.RG.BalabanCMP102Eq80SourcePi4CutoffCarrierAudit (9.7s)
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:3:0: 'YangMills.RG.CMP102Eq80SourcePi4PhysicalDomainLabel.properties' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:4:0: 'YangMills.RG.cmp102Eq80SourcePi4LocalizationDomain' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:5:0: 'YangMills.RG.cmp102Eq80SourcePi4BondDomainFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:6:0: 'YangMills.RG.cmp102Eq80SourcePi4PhysicalY0' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:7:0: 'YangMills.RG.cmp102Eq80SourcePi4LocalizationDomain_bondSupport_subset_physicalY0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4CutoffCarrierAudit.lean:8:0: 'YangMills.RG.cmp98SourceFieldSupNorm_eq80DomainProjection_le_threshold_of_cutoffFactor_ne_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10251/10322] Built YangMills.RG.BalabanCMP102Eq80CouplingScaledEq143SourceMetric (23s)
# ℹ [10252/10322] Built YangMills.RG.BalabanCMP116CenteredConditionedCombinedEq80PartialPotentialAudit (18s)
# info: YangMills/RG/BalabanCMP116CenteredConditionedCombinedEq80PartialPotentialAudit.lean:3:0: 'YangMills.RG.cmp116CenteredConditionedCombinedEq80PartialTotal' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116CenteredConditionedCombinedEq80PartialPotentialAudit.lean:4:0: 'YangMills.RG.cmp116CenteredConditionedCombinedEq80PartialResidual' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116CenteredConditionedCombinedEq80PartialPotentialAudit.lean:5:0: 'YangMills.RG.cmp116CenteredConditionedCombinedEq80PartialTotal_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116CenteredConditionedCombinedEq80PartialPotentialAudit.lean:6:0: 'YangMills.RG.cmp116CenteredConditionedCombinedEq80PartialResidual_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10253/10322] Built YangMills.RG.BalabanCMP116CenteredConditionedCombinedEq80PartialEq136 (26s)
# ✔ [10254/10324] Built YangMills.RG.LocalQuantitativeComposition (6.7s)
# ℹ [10255/10324] Built YangMills.RG.BalabanCMP102Eq80CutoffRadialResidualAudit (19s)
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:3:0: 'YangMills.RG.norm_physicalBondProjection_le_sqrt_card_mul_sourceSupNorm' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:4:0: 'YangMills.RG.cmp98SourceFieldSupNorm_smul' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:5:0: 'YangMills.RG.cmp98SourceFieldSupNorm_le_of_mem_segment_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:6:0: 'YangMills.RG.cmp98SourceFieldSupNorm_eq80DomainProjection_segment_le_threshold_of_cutoffFactor_ne_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:7:0: 'YangMills.RG.norm_physicalBondProjection_le_sqrt_card_mul_of_projected_sourceSupNorm_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:8:0: 'YangMills.RG.norm_cmp116LocalizationDomainProjection_le_explicitBlockCard_mul_threshold' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CutoffRadialResidualAudit.lean:9:0: 'YangMills.RG.abs_half_inner_cmp116RadialTaylorResidualOperator_eq80DomainProjection_le_of_cutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10256/10326] Built YangMills.RG.QuantitativeFixedPointThirdDerivativeStability (14s)
# ℹ [10257/10326] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit (19s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:3:0: 'YangMills.RG.cmp102PartialPropagatorJetThirdFieldDerivative_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:4:0: 'YangMills.RG.norm_cmp102PartialPropagatorJetThirdFieldDerivative_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_fixedFirstSlice_normed_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp102PartialPropagatorJet_one_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:7:0: 'YangMills.RG.norm_cmp102Eq80PhysicalFineHeadTailDomainCoefficientThirdFieldDerivative_le_sourceJets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainCoefficientThirdFieldDerivativeAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp102Eq80PhysicalFineHeadTailDomainCoefficient_le_sourceJets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10258/10328] Built YangMills.RG.BalabanCMP102Eq80CouplingScaledEq143SourceMetricAudit (16s)
# info: YangMills/RG/BalabanCMP102Eq80CouplingScaledEq143SourceMetricAudit.lean:3:0: 'YangMills.RG.cmp102Eq80CouplingScaledEq143Cost' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CouplingScaledEq143SourceMetricAudit.lean:4:0: 'YangMills.RG.CMP102Eq80CouplingScaledEq143ProducerBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CouplingScaledEq143SourceMetricAudit.lean:5:0: 'YangMills.RG.cmp102Eq80PhysicalDomainFTCSecondFieldSourceMetricMajorant_mul_couplingCost_le_eq143' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80CouplingScaledEq143SourceMetricAudit.lean:6:0: 'YangMills.RG.abs_cmp116FDerivHessian_cmp102Eq80CouplingScaledPhysicalDomainFTC_le_eq143' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10259/10328] Built YangMills.RG.BalabanCMP116CenteredConditionedCombinedEq80PartialEq136Audit (13s)
# info: YangMills/RG/BalabanCMP116CenteredConditionedCombinedEq80PartialEq136Audit.lean:3:0: 'YangMills.RG.abs_cmp116CenteredConditionedCombinedEq80PartialResidual_le_eq136' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10260/10334] Built YangMills.RG.LocalQuantitativeCompositionAudit (8.0s)
# info: YangMills/RG/LocalQuantitativeCompositionAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_comp_le_at' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/LocalQuantitativeCompositionAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_comp_le_at_of_both_local' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/LocalQuantitativeCompositionAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_two_bilinear_le_at' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10261/10336] Built YangMills.RG.LocalSecondJetFromDerivativeLipschitz (5.3s)
# ✔ [10262/10336] Built YangMills.RG.LocalThirdJetFromSecondJetLipschitz (5.9s)
# ✔ [10263/10338] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointJetZero (20s)
# ✔ [10264/10338] Built YangMills.RG.AnalyticThirdDerivativeChangeOriginBound (7.2s)
# ℹ [10265/10340] Built YangMills.RG.LocalSecondJetFromDerivativeLipschitzAudit (4.0s)
# info: YangMills/RG/LocalSecondJetFromDerivativeLipschitzAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_two_le_of_eventually_fderiv_lipschitz' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10266/10340] Built YangMills.RG.LocalThirdJetFromSecondJetLipschitzAudit (4.5s)
# info: YangMills/RG/LocalThirdJetFromSecondJetLipschitzAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_three_le_of_eventually_secondJet_lipschitz' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10267/10340] Built YangMills.RG.QuantitativeFixedPointThirdDerivativeStabilityAudit (14s)
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:3:0: 'YangMills.RG.fderiv_fixedPoint_eq_firstDerivativeMap' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:4:0: 'YangMills.RG.norm_fderiv_fixedPointFirstDerivativeMap_vertical_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:5:0: 'YangMills.RG.lipschitzOnWith_fderiv_of_iteratedFDeriv_two_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_three_fixedPoint_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_three_fixedPoint_le_of_derivedSecond' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointThirdDerivativeStabilityAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_three_fixedPoint_le_of_derivedSecond_on_tube' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10268/10352] Built YangMills.RG.BalabanCMP102Eq80PhysicalIndexedEq143 (37s)
# ✔ [10269/10352] Built YangMills.RG.QuantitativeFixedPointDerivedMapSecondJet (27s)
# ℹ [10270/10353] Built YangMills.RG.AnalyticThirdDerivativeChangeOriginBoundAudit (9.7s)
# info: YangMills/RG/AnalyticThirdDerivativeChangeOriginBoundAudit.lean:3:0: 'YangMills.RG.thirdDerivativeChangeOriginBallBudget_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/AnalyticThirdDerivativeChangeOriginBoundAudit.lean:4:0: 'YangMills.RG.six_mul_norm_changeOrigin_three_le_ballBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/AnalyticThirdDerivativeChangeOriginBoundAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_three_le_six_mul_changeOrigin' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/AnalyticThirdDerivativeChangeOriginBoundAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_three_le_changeOriginBallBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10271/10353] Built YangMills.RG.NearLogExpThirdDerivativeChangeOriginBound (10s)
# ✔ [10272/10354] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointFirstJet (16s)
# ✔ [10273/10354] Built YangMills.RG.ExpSecondDerivativeBound (13s)
# ℹ [10274/10354] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit (21s)
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit.lean:3:0: 'YangMills.RG.cmp102AmbientNonlinearBlock_zero_mul_inverseAtZero_source' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit.lean:4:0: 'YangMills.RG.fderiv_cmp102IntrinsicAmbientCorrectionBond_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit.lean:5:0: 'YangMills.RG.fderiv_cmp102IntrinsicPhysicalCorrectionBondCoord_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit.lean:6:0: 'YangMills.RG.fderiv_cmp102IntrinsicPhysicalNonlinearCorrectionSup_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointJetZeroAudit.lean:7:0: 'YangMills.RG.fderiv_cmp102IntrinsicPhysicalBackgroundCorrectionMapUncurry_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10275/10354] Built YangMills.RG.BalabanCMP116Eq226PhysicalContourCutoffSupportAudit (13s)
# info: YangMills/RG/BalabanCMP116Eq226PhysicalContourCutoffSupportAudit.lean:3:0: 'YangMills.RG.CMP116Eq214PhysicalContourDensity.nestedCauchyBoundaryBound_of_outerInteractionEnergy_cutoffSupport_expCard' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10276/10354] Built YangMills.RG.BalabanCMP102Eq80PhysicalIndexedEq143Audit (15s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalIndexedEq143Audit.lean:3:0: 'YangMills.RG.cmp116Eq142PhysicalQuadraticCore_indexedContour_eq_half_projectedHessian' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalIndexedEq143Audit.lean:4:0: 'YangMills.RG.abs_cmp116FDerivHessian_cmp116Eq142PhysicalQuadraticCore_indexedContour_le_eq143' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10277/10354] Built YangMills.RG.QuantitativeFixedPointDerivedMapSecondJetAudit (13s)
# info: YangMills/RG/QuantitativeFixedPointDerivedMapSecondJetAudit.lean:3:0: 'YangMills.RG.norm_fixedPointGraphFactorLinear_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointDerivedMapSecondJetAudit.lean:4:0: 'YangMills.RG.contDiff_fixedPointGraphFactor' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointDerivedMapSecondJetAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_one_fixedPointGraphFactor_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointDerivedMapSecondJetAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointGraphFactor' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointDerivedMapSecondJetAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointFirstDerivativeMap_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10278/10354] Built YangMills.RG.QuantitativeFixedPointCoefficientJets (19s)
# ⚠ [10279/10354] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedHessianSupport (24s)
# warning: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedHessianSupport.lean:301:6: try 'simp' instead of 'simpa'
#
# Note: This linter can be disabled with `set_option linter.unnecessarySimpa false`
# ✔ [10280/10357] Built YangMills.RG.BalabanCMP102Eq80PhysicalCombinedEq143 (27s)
# ✔ [10281/10357] Built YangMills.RG.BalabanCMP102AmbientOrientedEdgeThirdJetBound (19s)
# ℹ [10282/10357] Built YangMills.RG.BalabanCMP116Eq226PhysicalContourCutoffSupportResidualLedgerAudit (14s)
# info: YangMills/RG/BalabanCMP116Eq226PhysicalContourCutoffSupportResidualLedgerAudit.lean:3:0: 'YangMills.RG.CMP116Eq214PhysicalContourDensity.norm_term_le_eq226SourceTermWeight_of_outerInteractionEnergy_cutoffSupport_residualLedger' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10283/10357] Built YangMills.RG.NearLogExpThirdDerivativeChangeOriginBoundAudit (18s)
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:3:0: 'YangMills.RG.nearLogThirdDerivativeChangeOriginBudget_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:4:0: 'YangMills.RG.expThirdDerivativeChangeOriginBudget_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:5:0: 'YangMills.RG.nearLogThirdDerivativeBallBudget_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:6:0: 'YangMills.RG.expThirdDerivativeBallBudget_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_three_nearLog_le_changeOriginBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_three_nearLog_le_ballBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:9:0: 'YangMills.RG.norm_iteratedFDeriv_three_exp_le_changeOriginBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/NearLogExpThirdDerivativeChangeOriginBoundAudit.lean:10:0: 'YangMills.RG.norm_iteratedFDeriv_three_exp_le_ballBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10284/10357] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainThirdFieldSourceMetricBoundAudit (15s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainThirdFieldSourceMetricBoundAudit.lean:3:0: 'YangMills.RG.cmp102Eq80PhysicalDomainThirdFieldSourceMetricMajorant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainThirdFieldSourceMetricBoundAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp102Eq80PhysicalFineHeadTailDomainCoefficient_le_sourceMetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainThirdFieldSourceMetricBoundAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp102Eq80PhysicalFineHeadTailDomainCoefficient_le_sourceMetric_of_correctionJets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10285/10357] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointSecondJet (24s)
# ℹ [10286/10357] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointFirstJetAudit (19s)
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointFirstJetAudit.lean:3:0: 'YangMills.RG.cmp102SourceIntrinsicPhysicalBackgroundCorrectionMapDerivativeLipschitzBudget_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointFirstJetAudit.lean:4:0: 'YangMills.RG.norm_fderiv_cmp102IntrinsicPhysicalBackgroundCorrectionMapUncurry_apply_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointFirstJetAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_one_cmp102IntrinsicPhysicalBackgroundCorrectionMapUncurry_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10287/10359] Built YangMills.RG.QuantitativeFixedPointCoefficientJetsAudit (14s)
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_one_fixedPointCoefficientInput_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointCoefficientInput_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_one_fixedPointDerivativeCoefficient_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointDerivativeCoefficient_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointDerivativeCoefficient_le_of_jets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointFirstDerivativeMap_le_of_jets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10288/10359] Built YangMills.RG.QuantitativeFixedPointCoefficientJetsLocal (17s)
# ✔ [10289/10359] Built YangMills.RG.BalabanCMP102Eq80Eq220RateCompatibility (8.5s)
# ℹ [10290/10359] Built YangMills.RG.BalabanCMP102Eq80PhysicalCombinedEq143Audit (10s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalCombinedEq143Audit.lean:3:0: 'YangMills.RG.abs_cmp116FDerivHessian_cmp116Eq80Lemma1CombinedPhysical_le_eq143' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10291/10361] Built YangMills.RG.BalabanCMP102Eq80RectangularOrderFourJetRadiusAudit (9.2s)
# info: YangMills/RG/BalabanCMP102Eq80RectangularOrderFourJetRadiusAudit.lean:3:0: 'YangMills.RG.cmp102Eq80RectangularOrderFourJetRadius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80RectangularOrderFourJetRadiusAudit.lean:4:0: 'YangMills.RG.cmp102Eq80JointRemainderRadius_orderFour_of_correctionJets' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10292/10361] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedTerminalEq143 (27s)
# ⚠ [10293/10361] Built YangMills.RG.BalabanCMP102AmbientWilsonLineThirdJetBound (18s)
# warning: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBound.lean:41:0: automatically included section variable(s) unused in theorem `YangMills.RG.norm_cmp102AmbientMatrixMulCLM_le_one`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBound.lean:61:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp102AmbientWilsonLineOrderThreeJetBudget_nonneg`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [10294/10363] Built YangMills.RG.BalabanCMP102PhysicalIntrinsicFixedPointSecondJetAudit (11s)
# info: YangMills/RG/BalabanCMP102PhysicalIntrinsicFixedPointSecondJetAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_two_cmp102IntrinsicPhysicalBackgroundCorrectionMapUncurry_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10295/10363] Built YangMills.RG.QuantitativeFixedPointCoefficientJetsLocalAudit (11s)
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsLocalAudit.lean:3:0: 'YangMills.RG.norm_iteratedFDeriv_one_fixedPointDerivativeCoefficient_le_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsLocalAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointDerivativeCoefficient_le_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsLocalAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointFirstDerivativeMap_le_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/QuantitativeFixedPointCoefficientJetsLocalAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_two_fixedPointFirstDerivativeMap_le_of_jets_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10296/10365] Built YangMills.RG.BalabanCMP109PhysicalLinearConstraint (13s)
# ℹ [10297/10365] Built YangMills.RG.BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit (24s)
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp102AmbientRightMulCLM_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:4:0: 'YangMills.RG.norm_physicalAmbientBondEvalCLM_le_one' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:5:0: 'YangMills.RG.norm_matrixConjTransposeCLM_le_one' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_three_physicalMatrixExp_eval_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_three_ambientOrientedEdgeMatrix_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_two_ambientOrientedEdgeMatrix_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:9:0: 'YangMills.RG.cmp102AmbientEdgeOrderThreeJetBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientOrientedEdgeThirdJetBoundAudit.lean:10:0: 'YangMills.RG.norm_iteratedFDeriv_ambientOrientedEdgeMatrix_le_orderThreeBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10298/10373] Built YangMills.RG.BalabanCMP102Eq80Eq220RateCompatibilityAudit (10s)
# info: YangMills/RG/BalabanCMP102Eq80Eq220RateCompatibilityAudit.lean:3:0: 'YangMills.RG.cmp102Eq80CanonicalRatio_mul_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80Eq220RateCompatibilityAudit.lean:4:0: 'YangMills.RG.cmp102Eq80CanonicalRatioCertificate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80Eq220RateCompatibilityAudit.lean:5:0: 'YangMills.RG.cmp102Eq80Eq220_branching_small_of_budget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80Eq220RateCompatibilityAudit.lean:6:0: 'YangMills.RG.ratio_le_exp_neg_rate_mul_10000_iff' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80Eq220RateCompatibilityAudit.lean:7:0: 'YangMills.RG.cmp102Eq80Eq220_metric_decay_iff' depends on axioms: [propext, Classical.choice, Quot.sound]
# ⚠ [10299/10373] Replayed YangMills.RG.BalabanCMP98ContourFirstVariationSupport
# warning: YangMills/RG/BalabanCMP98ContourFirstVariationSupport.lean:34:0: automatically included section variable(s) unused in theorem `YangMills.RG.orientedWilsonGenerator_eq_zero_of_apply_eq_zero`:
#   [NeZero d]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero d] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ⚠ [10300/10374] Replayed YangMills.RG.BalabanCMP98ContourPivotAvoidance
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:40:0: automatically included section variable(s) unused in theorem `YangMills.RG.finBox_shift_ne_of_two_le`:
#   [NeZero d]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero d] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:45:27: This simp argument is unused:
#   if_pos rfl
#
# Hint: Omit it from the simp argument list.
#   simp only [FinBox.shift,̵ ̵i̵f̵_̵p̵o̵s̵ ̵r̵f̵l̵] at hi
#
# Note: This linter can be disabled with `set_option linter.unusedSimpArgs false`
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:112:18: `Nat.lt.step` has been deprecated: Use `Nat.lt_succ_of_lt` instead
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.step` to `Nat.lt_succ_of_lt x`).
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:188:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99SourceUbarGamma1_avoids_constraintPivot`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:202:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99SourceUbarGamma3_avoids_constraintPivot`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:229:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99SourceUbarGamma2_avoids_constraintPivot_of_ne`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP98ContourPivotAvoidance.lean:254:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp98SourceCoarseBondPath_avoids_constraintPivot_of_ne`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ✔ [10301/10374] Built YangMills.RG.BalabanCMP102AmbientFourContourThirdJetBound (10s)
# ✔ [10302/10375] Built YangMills.RG.BalabanCMP109PhysicalConstraintRightInverse (13s)
# ℹ [10303/10375] Built YangMills.RG.BalabanCMP102AmbientWilsonLineThirdJetBoundAudit (15s)
# info: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp102AmbientMatrixMulCLM_le_one' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBoundAudit.lean:4:0: 'YangMills.RG.cmp102AmbientWilsonLineOrderThreeJetBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBoundAudit.lean:5:0: 'YangMills.RG.cmp102AmbientWilsonLineOrderThreeJetBudget_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientWilsonLineThirdJetBoundAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_cmp98AmbientWilsonLineMatrix_le_orderThreeBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10304/10376] Built YangMills.RG.BalabanCMP109IntrinsicConstraintCorrection (14s)
# warning: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrection.lean:76:8: automatically included section variable(s) unused in theorem `YangMills.RG.cmp109PhysicalConstraintShiftCLM_apply`:
#   [NeZero (L * N')]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero (L * N')] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ✔ [10305/10376] Built YangMills.RG.BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructor (48s)
# ✔ [10306/10376] Built YangMills.RG.BalabanCMP109PhysicalPivotNoMixing (11s)
# ✔ [10307/10377] Built YangMills.RG.BalabanCMP109PhysicalConstraintRightInverseSupport (8.4s)
# ℹ [10308/10378] Built YangMills.RG.BalabanCMP98ContourFirstVariationSupportAudit (16s)
# info: YangMills/RG/BalabanCMP98ContourFirstVariationSupportAudit.lean:3:0: 'YangMills.RG.orientedWilsonGenerator_eq_zero_of_apply_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP98ContourFirstVariationSupportAudit.lean:4:0: 'YangMills.RG.cmp98ContourFirstVariation_zero_of_generators' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP98ContourFirstVariationSupportAudit.lean:5:0: 'YangMills.RG.fderiv_cmp98AmbientWilsonLineMatrix_zero_apply_physical_of_support' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP98ContourFirstVariationSupportAudit.lean:6:0: 'YangMills.RG.fderiv_cmp98AmbientWilsonLineMatrix_zero_apply_single_of_avoids' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10309/10378] Built YangMills.RG.BalabanCMP102AmbientLocalNearLogThirdJetBound (12s)
# warning: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBound.lean:75:6: try 'simp' instead of 'simpa'
#
# Note: This linter can be disabled with `set_option linter.unnecessarySimpa false`
# ✔ [10310/10378] Built YangMills.RG.BalabanCMP102PhysicalExpAverageBackgroundLipschitz (14s)
# ℹ [10311/10378] Built YangMills.RG.BalabanCMP109PhysicalLinearConstraintAudit (23s)
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:3:0: 'YangMills.RG.cmp109PhysicalLinearConstraint' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:4:0: 'YangMills.RG.cmp109PhysicalLinearConstraint_apply' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:5:0: 'YangMills.RG.cmp109PhysicalLinearConstraint_add' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:6:0: 'YangMills.RG.cmp109PhysicalLinearConstraint_smul' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:7:0: 'YangMills.RG.cmp109PhysicalLinearConstraintCLM' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:8:0: 'YangMills.RG.cmp109PhysicalLinearConstraintCLM_apply' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:9:0: 'YangMills.RG.cmp109PhysicalPivotResponseCLM' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalLinearConstraintAudit.lean:10:0: 'YangMills.RG.cmp109PhysicalPivotResponseCLM_apply' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10312/10378] Built YangMills.RG.BalabanCMP102AmbientFourContourThirdJetBoundAudit (21s)
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:3:0: 'YangMills.RG.iteratedFDeriv_cmp98UbarAmbientDeviationMatrix_eq_sourceFourContour' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_cmp98UbarAmbientDeviationMatrix_le_lineBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:5:0: 'YangMills.RG.cmp102AmbientWilsonLineOrderThreeJetBudget_monotone' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:6:0: 'YangMills.RG.cmp102SourceFourContourOrderThreeJetBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_cmp98UbarAmbientDeviationMatrix_le_sourceLengthBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientFourContourThirdJetBoundAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp98UbarAmbientDeviationMatrix_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10313/10380] Built YangMills.RG.BalabanCMP109PhysicalConstraintRightInverseAudit (15s)
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseAudit.lean:3:0: 'YangMills.RG.cmp109PhysicalPivotResponse_comp_inverse' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseAudit.lean:4:0: 'YangMills.RG.cmp109PhysicalPivotInverse_comp_response' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseAudit.lean:5:0: 'YangMills.RG.cmp109PhysicalLinearConstraint_comp_rightInverse' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseAudit.lean:6:0: 'YangMills.RG.cmp109PhysicalLinearConstraint_rightInverse_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10314/10380] Built YangMills.RG.BalabanCMP109PhysicalPivotFlat (13s)
# warning: YangMills/RG/BalabanCMP109PhysicalPivotFlat.lean:101:8: automatically included section variable(s) unused in theorem `YangMills.RG.cmp98GAdInv_zero_apply`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [10315/10380] Built YangMills.RG.BalabanCMP109PhysicalConstraintRightInverseSupportAudit (14s)
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseSupportAudit.lean:3:0: 'YangMills.RG.cmp96ConstraintPivotInsertion_apply_of_not_pivot' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseSupportAudit.lean:4:0: 'YangMills.RG.cmp96ConstraintPivotInsertion_apply_pivot' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseSupportAudit.lean:5:0: 'YangMills.RG.cmp109PhysicalConstraintRightInverseCLM_apply_eq_zero_of_not_pivot' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalConstraintRightInverseSupportAudit.lean:6:0: 'YangMills.RG.cmp109PhysicalConstraintRightInverseCLM_apply_pivot' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10316/10380] Built YangMills.RG.BalabanCMP109PhysicalPivotInverseNoMixing (25s)
# ℹ [10317/10381] Built YangMills.RG.BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit (29s)
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit.lean:10:0: 'YangMills.RG.cmp116CenteredConditionedCombinedPartialPreEq136_eq136' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit.lean:11:0: 'YangMills.RG.CMP116CenteredConditionedCombinedEq80LedgerIdentification.smooth' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit.lean:12:0: 'YangMills.RG.CMP116CenteredConditionedCombinedEq80LedgerIdentification.hessian_zero_off_support' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit.lean:13:0: 'YangMills.RG.CMP116CenteredConditionedCombinedEq80LedgerIdentification.alpha_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedPartialTermSourceConstructorAudit.lean:14:0: 'YangMills.RG.cmp116Eq226CenteredConditionedCombinedPartialTermSourceOfPreEq136' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10318/10382] Built YangMills.RG.BalabanCMP102AmbientLogAverageThirdJetBound (21s)
# ℹ [10319/10382] Built YangMills.RG.BalabanCMP109IntrinsicConstraintCorrectionAudit (35s)
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:3:0: 'YangMills.RG.contDiffAt_cmp109IntrinsicConstraintCorrectionMap_uncurry' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:4:0: 'YangMills.RG.cmp109ConstraintCorrectionMap_eq_intrinsic_of_mem' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:5:0: 'YangMills.RG.cmp109PhysicalConstraintCorrection_intrinsicEquation' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:6:0: 'YangMills.RG.cmp109IntrinsicConstraintCorrectionMap_fixedPoint_unique' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:7:0: 'YangMills.RG.cmp109IntrinsicConstraintCorrectionMap_fixedPoint_unique_across_certificates' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109IntrinsicConstraintCorrectionAudit.lean:8:0: 'YangMills.RG.cmp109PhysicalConstraintCorrectedFluctuation_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10320/10383] Built YangMills.RG.BalabanCMP102PhysicalRightInverseBackgroundLipschitz (10s)
# ℹ [10321/10383] Built YangMills.RG.BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit (21s)
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:3:0: 'YangMills.RG.cmp102SourceNearLogOrderThreeOuterBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:4:0: 'YangMills.RG.norm_iteratedFDeriv_nearLog_le_orderThreeOuterBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:5:0: 'YangMills.RG.cmp102SourceFourContourCompositionRadius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:6:0: 'YangMills.RG.cmp102SourceLocalNearLogThirdJetBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_nearLog_cmp98UbarAmbientDeviationMatrix_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLocalNearLogThirdJetBoundAudit.lean:8:0: 'YangMills.RG.norm_iteratedFDeriv_three_nearLog_cmp98UbarAmbientDeviationMatrix_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10322/10385] Built YangMills.RG.BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit (15s)
# info: YangMills/RG/BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit.lean:3:0: 'YangMills.RG.cmp98UbarExpAveragePhysicalVariation' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit.lean:4:0: 'YangMills.RG.cmp102PhysicalExpAverageBackgroundValueBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit.lean:5:0: 'YangMills.RG.cmp102PhysicalExpAverageBackgroundDerivativeBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit.lean:6:0: 'YangMills.RG.norm_cmp98UbarExpAveragePhysicalVariation_le_sourceScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalExpAverageBackgroundLipschitzAudit.lean:7:0: 'YangMills.RG.norm_cmp98UbarExpAverage_zero_sub_trivial_le_sourceScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10323/10386] Built YangMills.RG.BalabanCMP102AmbientExpAverageThirdJetBound (12s)
# ✔ [10324/10388] Built YangMills.RG.BalabanCMP102PhysicalBlockDerivativeBackgroundLipschitz (11s)
# ℹ [10325/10389] Built YangMills.RG.BalabanCMP102AmbientLogAverageThirdJetBoundAudit (19s)
# info: YangMills/RG/BalabanCMP102AmbientLogAverageThirdJetBoundAudit.lean:3:0: 'YangMills.RG.iteratedFDeriv_finset_sum_apply_of_contDiffAt' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLogAverageThirdJetBoundAudit.lean:4:0: 'YangMills.RG.iteratedFDeriv_cmp98UbarLogAverage_eq_normalized_sum' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLogAverageThirdJetBoundAudit.lean:5:0: 'YangMills.RG.iteratedFDeriv_three_cmp98UbarLogAverage_eq_normalized_sum' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLogAverageThirdJetBoundAudit.lean:6:0: 'YangMills.RG.norm_iteratedFDeriv_cmp98UbarLogAverage_le_sourceBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientLogAverageThirdJetBoundAudit.lean:7:0: 'YangMills.RG.norm_iteratedFDeriv_three_cmp98UbarLogAverage_le_sourceBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10326/10389] Built YangMills.RG.BalabanCMP102PhysicalRightInverseBackgroundLipschitzAudit (11s)
# info: YangMills/RG/BalabanCMP102PhysicalRightInverseBackgroundLipschitzAudit.lean:3:0: 'YangMills.RG.cmp102PhysicalRightInverseBackgroundBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalRightInverseBackgroundLipschitzAudit.lean:4:0: 'YangMills.RG.cmp102PhysicalRightInverseBackgroundBudget_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102PhysicalRightInverseBackgroundLipschitzAudit.lean:5:0: 'YangMills.RG.norm_cmp98Eq119NonlinearBlockInverseAtZero_sub_trivial_le_sourceScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10327/10389] Built YangMills.RG.BalabanCMP109PhysicalPivotInverseNoMixingAudit (26s)
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:3:0: 'YangMills.RG.cmp109PhysicalPivotResponseCLM_apply_congr' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:4:0: 'YangMills.RG.cmp109PhysicalPivotDefectCLM_apply_congr' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:5:0: 'YangMills.RG.cmp109PhysicalPivotDefect_neg_pow_apply_congr' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:6:0: 'YangMills.RG.cmp109PhysicalPivotInverseCLM_apply_congr' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:7:0: 'YangMills.RG.cmp109PhysicalPivotInverseCLM_apply_eq_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:8:0: 'YangMills.RG.cmp109PhysicalConstraintRightInverseCLM_apply_pivot_congr' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotInverseNoMixingAudit.lean:9:0: 'YangMills.RG.cmp109PhysicalConstraintRightInverseCLM_apply_pivot_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10328/10389] Built YangMills.RG.BalabanCMP109PhysicalPivotFlatAudit (31s)
# info: YangMills/RG/BalabanCMP109PhysicalPivotFlatAudit.lean:3:0: 'YangMills.RG.cmp98Eq124EntrancePrefixRightVariation_single_pivot_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109PhysicalPivotFlatAudit.lean:4:0: 'YangMills.RG.cmp98Eq124ExitPrefixRightVariation_single_pivot_eq_zero' depends on axioms: [propext,
#  Classical.choice,
# ...
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:4:0: 'YangMills.RG.cmp99Eq337PhysicalAmplitudeMajorant' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:5:0: 'YangMills.RG.cmp99Eq337PhysicalCovariantDerivativeMajorant' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:6:0: 'YangMills.RG.CMP99Eq337PhysicalRealPerturbationDomain' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:7:0: 'YangMills.RG.CMP99Eq337PhysicalRealPerturbationDomain.abs_eta_mul_amplitudeMajorant_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:8:0: 'YangMills.RG.CMP99Eq337PhysicalRealPerturbationDomain.amplitude_bound_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq337PhysicalRealPerturbationDomainAudit.lean:9:0: 'YangMills.RG.CMP99Eq337PhysicalRealPerturbationDomain.covariant_derivative_bound_at' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10992/11012] Built YangMills.RG.BalabanCMP99SpecialUnitaryToSpecialLinearRealSlice (7.5s)
# ⚠ [10993/11012] Built YangMills.RG.BalabanCMP99SourceSeparatedGeneratedFlatPhysicalLocalizedFieldB0 (7.1s)
# warning: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalLocalizedFieldB0.lean:35:0: automatically included section variable(s) unused in theorem `YangMills.RG.finitePiLp_of_supportedInIdentityOwner_eq_flatComplexFibrePointSource`:
#   [NeZero Nc]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Nc] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ⚠ [10994/11012] Built YangMills.RG.BalabanCMP99ComplexSpecialLinearAdjointComposition (6.5s)
# warning: YangMills/RG/BalabanCMP99ComplexSpecialLinearAdjointComposition.lean:32:2: 'change
#   ((g * h : Matrix.SpecialLinearGroup (Fin Nc) ℂ) : Matrix (Fin Nc) (Fin Nc) ℂ) * cmp99SUNLieComplexCoordMatrixLM Nc Z *
#       (((g * h : Matrix.SpecialLinearGroup (Fin Nc) ℂ)⁻¹ : Matrix.SpecialLinearGroup (Fin Nc) ℂ) :
#         Matrix (Fin Nc) (Fin Nc) ℂ) =
#     (g : Matrix (Fin Nc) (Fin Nc) ℂ) *
#         ((h : Matrix (Fin Nc) (Fin Nc) ℂ) * cmp99SUNLieComplexCoordMatrixLM Nc Z *
#           ((h⁻¹ : Matrix.SpecialLinearGroup (Fin Nc) ℂ) : Matrix (Fin Nc) (Fin Nc) ℂ)) *
#       ((g⁻¹ : Matrix.SpecialLinearGroup (Fin Nc) ℂ) : Matrix (Fin Nc) (Fin Nc) ℂ)' tactic does nothing
#
# Note: This linter can be disabled with `set_option linter.unusedTactic false`
# ℹ [10995/11012] Built YangMills.RG.BalabanCMP99Eq351ExponentialAdjointRemainderBoundAudit (7.2s)
# info: YangMills/RG/BalabanCMP99Eq351ExponentialAdjointRemainderBoundAudit.lean:3:0: 'YangMills.RG.cmp99Eq351_expTailMajorant_le_four_thirds_sq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351ExponentialAdjointRemainderBoundAudit.lean:4:0: 'YangMills.RG.cmp99Eq351_norm_exp_neg_le_four_thirds' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351ExponentialAdjointRemainderBoundAudit.lean:5:0: 'YangMills.RG.norm_cmp99Eq351ExponentialAdjointRemainderCLM_apply_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10996/11012] Built YangMills.RG.BalabanCMP99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0Audit (13s)
# info: YangMills/RG/BalabanCMP99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0Audit.lean:3:0: 'YangMills.RG.cmp99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0Audit.lean:4:0: 'YangMills.RG.cmp99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceSeparatedSourceFlowFlatPhysicalPointSourceB0Audit.lean:5:0: 'YangMills.RG.norm_cmp99SourceSeparatedSourceFlowFlatPhysicalGreenQprimeStar_pointSource_apply_siteEquiv_le_pointSourceB0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10997/11012] Built YangMills.RG.BalabanCMP99Eq359OneScaleRealSlice (8.2s)
# warning: YangMills/RG/BalabanCMP99Eq359OneScaleRealSlice.lean:27:8: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99SUNHolonomyToSpecialLinear_apply`:
#   [NeZero M]
#   [NeZero N']
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero M] [NeZero N'] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [10998/11012] Built YangMills.RG.BalabanCMP99SourceSeparatedGeneratedFlatPhysicalPointSourceB0Audit (13s)
# info: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalPointSourceB0Audit.lean:3:0: 'YangMills.RG.cmp99SourceSeparatedGeneratedFlatPhysicalPointSourceB0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalPointSourceB0Audit.lean:4:0: 'YangMills.RG.cmp99SourceSeparatedGeneratedFlatPhysicalPointSourceB0_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalPointSourceB0Audit.lean:5:0: 'YangMills.RG.norm_cmp99SourceSeparatedGeneratedFlatPhysicalGreenQprimeStar_pointSource_apply_siteEquiv_le_pointSourceB0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10999/11012] Built YangMills.RG.BalabanCMP99ComplexSpecialLinearAdjointCompositionAudit (6.8s)
# info: YangMills/RG/BalabanCMP99ComplexSpecialLinearAdjointCompositionAudit.lean:8:0: 'YangMills.RG.cmp99SpecialLinearAdjointCoordLM_mul' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [11000/11012] Built YangMills.RG.BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit (9.9s)
# info: YangMills/RG/BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit.lean:3:0: 'YangMills.RG.cmp99SUNToSpecialLinear' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit.lean:4:0: 'YangMills.RG.cmp99SUNToSpecialLinear_coe' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit.lean:5:0: 'YangMills.RG.cmp99SUNToSpecialLinear_inv_coe' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit.lean:6:0: 'YangMills.RG.cmp99SpecialLinearAdjointCoordLM_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SpecialUnitaryToSpecialLinearRealSliceAudit.lean:7:0: 'YangMills.RG.cmp99SpecialLinearAdjointCoordLM_realSlice_inv' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [11001/11012] Built YangMills.RG.BalabanCMP99SourceSeparatedGeneratedFlatPhysicalLocalizedFieldB0Audit (9.6s)
# info: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalLocalizedFieldB0Audit.lean:3:0: 'YangMills.RG.finitePiLp_of_supportedInIdentityOwner_eq_flatComplexFibrePointSource' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceSeparatedGeneratedFlatPhysicalLocalizedFieldB0Audit.lean:4:0: 'YangMills.RG.norm_cmp99SourceSeparatedGeneratedFlatPhysicalGreenQprimeStar_localizedField_apply_siteEquiv_le_pointSourceB0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11002/11012] Built YangMills.RG.BalabanCMP99PhysicalBackgroundRealSlice (5.9s)
# ℹ [11003/11012] Built YangMills.RG.BalabanCMP99Eq359OneScaleRealSliceAudit (7.3s)
# info: YangMills/RG/BalabanCMP99Eq359OneScaleRealSliceAudit.lean:3:0: 'YangMills.RG.cmp99SUNHolonomyToSpecialLinear' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq359OneScaleRealSliceAudit.lean:4:0: 'YangMills.RG.cmp99SUNHolonomyToSpecialLinear_apply' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq359OneScaleRealSliceAudit.lean:5:0: 'YangMills.RG.cmp99ComplexAdjointBlockAverageCLM_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq359OneScaleRealSliceAudit.lean:6:0: 'YangMills.RG.cmp99ComplexAdjointBlockStarSynthesisCLM_realSlice' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11004/11012] Built YangMills.RG.BalabanCMP99Eq359TowerRealSliceAgreement (8.0s)
# ⚠ [11005/11012] Built YangMills.RG.BalabanCMP99Eq351PhysicalComplexPositiveBondFactorization (5.1s)
# warning: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorization.lean:50:8: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99Eq351PhysicalComplexPositiveExponentSL_coe`:
#   [NeZero d]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero d] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorization.lean:60:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99Eq351PhysicalComplexPositiveGeneratorMatrix_neg`:
#   [NeZero d]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero d] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorization.lean:71:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp99Eq351PhysicalComplexPositiveExponentSL_inv_coe`:
#   [NeZero d]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero d] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ✔ [11006/11012] Built YangMills.RG.BalabanCMP99ComplexUbarSuccessorRealSlice (6.8s)
# ℹ [11007/11012] Built YangMills.RG.BalabanCMP99PhysicalBackgroundRealSliceAudit (7.5s)
# info: YangMills/RG/BalabanCMP99PhysicalBackgroundRealSliceAudit.lean:3:0: 'YangMills.RG.cmp99PhysicalGaugeBackgroundToSpecialLinear' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99PhysicalBackgroundRealSliceAudit.lean:4:0: 'YangMills.RG.cmp99PhysicalGaugeBackgroundToSpecialLinear_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99PhysicalBackgroundRealSliceAudit.lean:5:0: 'YangMills.RG.wilsonLine_cmp99PhysicalGaugeBackgroundToSpecialLinear' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99PhysicalBackgroundRealSliceAudit.lean:6:0: 'YangMills.RG.cmp99ComplexPhysicalBlockHolonomy_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99PhysicalBackgroundRealSliceAudit.lean:7:0: 'YangMills.RG.cmp99Eq337PhysicalComplexPerturbedBackground_realSlice' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11008/11012] Built YangMills.RG.BalabanCMP99Eq359TowerRealSliceAgreementAudit (7.1s)
# info: YangMills/RG/BalabanCMP99Eq359TowerRealSliceAgreementAudit.lean:3:0: 'YangMills.RG.CMP99Eq359TowerRealSliceAgreement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq359TowerRealSliceAgreementAudit.lean:4:0: 'YangMills.RG.CMP99Eq359TowerRealSliceAgreement.stop' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq359TowerRealSliceAgreementAudit.lean:5:0: 'YangMills.RG.CMP99Eq359TowerRealSliceAgreement.step' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [11009/11012] Built YangMills.RG.BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit (11s)
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:8:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPositiveGeneratorMatrix' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:9:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPositiveExponentSL' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:10:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPositiveExponentSL_coe' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:11:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPositiveGeneratorMatrix_neg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:12:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPositiveExponentSL_inv_coe' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq351PhysicalComplexPositiveBondFactorizationAudit.lean:13:0: 'YangMills.RG.cmp99Eq351PhysicalComplexPerturbedPositiveBondSL_eq_mul' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11010/11012] Built YangMills.RG.BalabanCMP99ComplexUbarSuccessorRealSliceAudit (18s)
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:3:0: 'YangMills.RG.cmp99UbarSpecialLinearExponent_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:4:0: 'YangMills.RG.cmp99UbarSpecialLinearBlockOfDeviationBudget_realSlice' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:5:0: 'YangMills.RG.cmp99SourceBaseCoarseBackground_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:6:0: 'YangMills.RG.cmp99SourceComplexLocalizedUbarDeviation_realSlice' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:7:0: 'YangMills.RG.CMP99ComplexLocalizedUbarDeviationCertificate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:8:0: 'YangMills.RG.CMP99PhysicalUbarDeviationCertificate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:9:0: 'YangMills.RG.cmp99SourceComplexLocalizedUbarBlock_realSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:10:0: 'YangMills.RG.cmp99SourceComplexLocalizedNextBackground_realSlice' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99ComplexUbarSuccessorRealSliceAudit.lean:11:0: 'YangMills.RG.cmp99SourceComplexLocalizedNextBackground_realSlice_ofFineSmall' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11011/11012] Built YangMillsCore (6.7s)
# Build completed successfully (11012 jobs).
#
# STAGE=05_c6d_step3_yang_mills_core_root EXIT=0 SECONDS=6674.005
# EVIDENCE_SHA256=2194af75d007eec4d27705bb2004b0d818d9e272848405aae923a02c767cdc6b
# EVIDENCE_ARCHIVE=/content/hrpoly-c6d-step3-localized-precision-evidence.tar.gz
# EVIDENCE_ARCHIVE_SHA256=e0b5f4f53aa7c5e875683906d42986feb9e7a6e061146f61f9d6192052a6e317
# FINAL_STATUS=PASS
# RUNTIME_UNASSIGN_DEFERRED_TO_LAUNCHER=1
# RUNTIME_UNASSIGN_REQUESTED=1
# EVIDENCE_DOWNLOAD_REQUESTED=1
# LAUNCHER_EXIT=0
# RUNTIME_RETAINED_FOR_EVIDENCE=1
