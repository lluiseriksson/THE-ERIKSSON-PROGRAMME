# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/33180094de7882e87d513f8713b7bf508fb475c3/scripts/colab_p0_p9_prefix_combes_thomas_validation.py"
RUNNER_SHA256 = "feb858d7f990b5f29c0a64aa3dcd62011fe494b93fffe930a5daf4179de4e2ba"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
runner_hash = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + runner_hash, flush=True)
if runner_hash != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
release_runtime = runtime.unassign
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    print("LAUNCHER_RUNTIME_RELEASE_REQUESTED=1", flush=True)
    release_runtime()
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")

# %%
from pathlib import Path
import hashlib, json
E=Path('/content/hrpoly-p0-p9-prefix-combes-thomas-evidence')
A=Path('/content/hrpoly-p0-p9-prefix-combes-thomas-evidence.tar.gz')
print('RECOVERY_FILES=' + ','.join(sorted(p.name for p in E.glob('*'))))
print('ARCHIVE_EXISTS=' + str(A.exists()))
if A.exists(): print('ARCHIVE_SHA256=' + hashlib.sha256(A.read_bytes()).hexdigest())
P=E/'evidence.json'
print('EVIDENCE_EXISTS=' + str(P.exists()))
if P.exists(): print(P.read_text())
# Out:
# RECOVERY_FILES=evidence.json
# ARCHIVE_EXISTS=True
# ARCHIVE_SHA256=660d20769b324e15659f1e0045238053566cda77084639589b3fc160bc513d15
# EVIDENCE_EXISTS=True
# {"closed_utc":"2026-08-18T17:20:42.305507+00:00","mathlib_sha":"07642720480157414db592fa85b626dafb71355b","opened_utc":"2026-08-18T16:44:38.494518+00:00","records":[{"exit":0,"output_sha256":"b3a6ec867fbe46f149dbd24f0d688792e89b0c85f35077f5d8271c1a42c6dc47","seconds":5.561918590999994,"stage":"download_toolchain"},{"exit":0,"output_sha256":"d90621fbbebef99d7cc656167901cbea6256057c28edd9a40873a127175f4ad8","seconds":6.338544933999856,"stage":"apt_update"},{"exit":0,"output_sha256":"542e8d835b48906854cfb90e6d7f88b929ea5fec2c5ef082e6b8d3cb421a3892","seconds":6.6317587349999485,"stage":"install_zstd"},{"exit":0,"output_sha256":"e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855","seconds":8.469998851000128,"stage":"extract_toolchain"},{"exit":0,"output_sha256":"ffc062887a88810ba8aa56371c6f0ef93d49dad1c0bc7fe99a8d7b264d3db0b1","seconds":0.03850932900013504,"stage":"lean_version"},{"exit":0,"output_sha256":"9f4a3130a140a735d63f1028a8437b9eb7a7b0fcea54f373c31fadd0fe5f43c6","seconds":0.040280298000197945,"stage":"lake_version"},{"exit":0,"output_sha256":"1caa3121478f6023e512df0c5da2ce44e878bd88ed7923f86f36405f4ac12d01","seconds":11.899365964000026,"stage":"clone"},{"exit":0,"output_sha256":"1fc9b3d9d7bc5b3dea69c3788e37587bc828c23dbdf3dd3a08453fb16af5683d","seconds":1.39456740300011,"stage":"checkout"},{"exit":0,"output_sha256":"c67af0a0576794d3bb73ae59189962d6dd86a8b409e3cbc38f21838a12f9e740","seconds":0.002620010000100592,"stage":"head"},{"exit":0,"output_sha256":"7b76e5468f98eb0a10e30ecf9bf03dd0162b139b4abaebf80fb638383f394e51","seconds":0.13042566500007524,"stage":"overlay_text_guard"},{"exit":0,"output_sha256":"1eee979f85f5a4addaa25ef4611c98d84b8fc178747b1b12ee44152b26717ea2","seconds":0.09092114699978993,"stage":"import_prefix_guard"},{"exit":0,"output_sha256":"4dd5b03708c09b7e9a3cbec134a2bc93f694ddf023e2b4fa163d076483c9b9a6","seconds":105.34601249199977,"stage":"lake_update"},{"exit":0,"output_sha256":"a2fa5070e2d7c78dce69980ad09098922cf74cea781f2be21a6e899f21dc84cd","seconds":0.003508740000143007,"stage":"mathlib_pin"},{"exit":0,"output_sha256":"18cfb29942326ace51032bafb8c557fb732db93edb34b6930fc372497a2503c1","seconds":5.815644022000015,"stage":"cache_get"},{"exit":0,"output_sha256":"edd1f4d34ed82c9f574c4ae666943f6fe3e1991944fb6f26e1c8e04a1be24817","seconds":0.13941437599987694,"stage":"p0_p9_static_gate"},{"exit":0,"output_sha256":"ad7dde3349135cb64525760f6c3e7b60af08a2446238357befe1b3e3cd84b3f5","seconds":0.3627765879996332,"stage":"p0_p9_static_selftest"},{"exit":0,"output_sha256":"2a1c485cbcba8ed3683a8ca7067329410d34d4eaa8e7986f2f817edce622fd3f","seconds":67.86974090600006,"stage":"p0_p9_p2b_algebra_repro"},{"exit":0,"output_sha256":"e7c9249eaf8f2b778c86223b478ba68324bad156dfc4f1dedb730be7f873c931","seconds":1787.4156053250003,"stage":"p0_p9_materialize_project_prerequisites"},{"exit":0,"output_sha256":"e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855","seconds":0.009615660000235948,"stage":"p0_p9_prepare_scratch_build_dir"},{"exit":0,"output_sha256":"6ebc6495c108d6e0f5c6c0725fb73215e996e5c03fdd5d52322abfbf1dcb3737","seconds":9.1637489929999,"stage":"p0_p9_01_p0canonicalprefixtower"},{"exit":0,"output_sha256":"d65ea7906473b0b1dae35add9f6d101161b1e1e5a291839a7eec544c477ef94a","seconds":16.19240774700029,"stage":"p0_p9_02_p0canonicalprefixtoweraudit"},{"exit":0,"output_sha256":"e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855","seconds":7.311373440000352,"stage":"p0_p9_03_p1coefficientmonotonicity"},{"exit":0,"output_sha256":"4f4a9c9ab60ac66a721af6580ee85dcb8b045897b13f4e6adc3c0dd2f945399d","seconds":11.352757270999973,"stage":"p0_p9_04_p1coefficientmonotonicityaudit"},{"exit":0,"output_sha256":"e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855","seconds":10.686262382999303,"stage":"p0_p9_05_p2sourcecoefficientcoercivity"},{"exit":0,"output_sha256":"3092407ccf7c7916f3829899450a6aa060e320d0e5f981c796da8d6ef24b5cc9","seconds":49.45982035900033,"stage":"p0_p9_06_p2sou ...

# %%
import subprocess
cmd=['lake','env','lean','tmp/P2cCoarseCovariance.lean','-o','.lake/build/lib/lean/tmp/P2cCoarseCovariance.olean']
r=subprocess.run(cmd,cwd='/content/hrpoly-p0-p9-prefix-combes-thomas',stdout=subprocess.PIPE,stderr=subprocess.STDOUT,text=True)
print('P2C_DIAGNOSTIC_EXIT='+str(r.returncode))
print(r.stdout)
