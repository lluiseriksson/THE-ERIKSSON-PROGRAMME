# %%
import hashlib, urllib.request
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/8de7bbc980f58a6ab7152537a701251138cae4b7/scripts/colab_cmp89_eq246_directed_normalized_physical_fine_kernel_validation.py"
RUNNER_SHA256 = "adda65153f8902577bda1f03d390185e72558c941f9da989913dc88b86e538f2"
with urllib.request.urlopen(RUNNER_URL, timeout=60) as response:
    runner_source = response.read()
runner_hash = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + runner_hash, flush=True)
if runner_hash != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
launcher_exit = 0
runner_namespace = {"__name__": "__main__"}
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), runner_namespace)
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
runner_module = runner_namespace.get("runner")
archive = getattr(runner_module, "ARCHIVE", None)
if archive is not None and archive.is_file():
    archive_hash = hashlib.sha256(archive.read_bytes()).hexdigest()
    print("LAUNCHER_EVIDENCE_ARCHIVE=" + str(archive), flush=True)
    print("LAUNCHER_EVIDENCE_ARCHIVE_SHA256=" + archive_hash, flush=True)
print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
print("LAUNCHER_RUNTIME_RETAINED=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")

# %%
import subprocess, time
repo = "/content/hrpoly-cmp89-eq246-domain-cycle-uniqueness-cold-v1"
cmd = ["lake", "build", "YangMills.RG.BalabanCMP89Eq246AliasCycleTransport"]
print("DEBUG_STAGE=alias_cycle_transport_focal", flush=True)
print("DEBUG_CMD=" + repr(cmd), flush=True)
t0 = time.perf_counter()
p = subprocess.run(cmd, cwd=repo, text=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
print(p.stdout, end="", flush=True)
print("DEBUG_EXIT=" + str(p.returncode), flush=True)
print("DEBUG_SECONDS=" + format(time.perf_counter() - t0, ".3f"), flush=True)
# Out:
# DEBUG_STAGE=alias_cycle_transport_focal
# DEBUG_CMD=['lake', 'build', 'YangMills.RG.BalabanCMP89Eq246AliasCycleTransport']
# ⚠ [3303/3368] Replayed YangMills.RG.BalabanCMP99GeneralizedRandomWalk
# ...
#   [DecidableEq Domain]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [DecidableEq Domain] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [8186/8231] Replayed YangMills.KP.PlaneTreeCatalan
# info: YangMills/KP/PlaneTreeCatalan.lean:211:0: 'RootedTreeCatalan.PlaneTree.card_treesOfSizeSucc' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/KP/PlaneTreeCatalan.lean:212:0: 'RootedTreeCatalan.PlaneTree.mem_treesOfSizeSucc' depends on axioms: [propext, Classical.choice, Quot.sound]
# ...
