# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/a297c71b27d20de6980edc406e38c59074053dae/scripts/colab_finite_pilp_distance_rescaling_validation.py"
RUNNER_SHA256 = "e2fe6304819325b4c8f143f6305e1e8846bb0f7e4a9aefcbca1b9f5dc4b83f77"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
release_runtime = runtime.unassign
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    if launcher_exit == 0:
        print("RUNTIME_RETAINED_FOR_EVIDENCE_DOWNLOAD=1", flush=True)
    else:
        print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
#  Classical.choice,
#  Quot.sound]
# ℹ [10404/10620] Built YangMills.RG.BalabanCMP89Eq251AliasWeightRedistributionAudit (10s)
# info: YangMills/RG/BalabanCMP89Eq251AliasWeightRedistributionAudit.lean:10:0: 'YangMills.RG.abs_le_cmp89Eq251EuclideanNorm' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251AliasWeightRedistributionAudit.lean:11:0: 'YangMills.RG.pi_le_cmp89Eq251EuclideanNorm_shift' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251AliasWeightRedistributionAudit.lean:12:0: 'YangMills.RG.one_add_abs_alias_le_three_mul_cmp89Eq251EuclideanNorm_shift' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251AliasWeightRedistributionAudit.lean:13:0: 'YangMills.RG.cmp89Eq251AliasExcessProduct_div_euclideanNorm_rpow_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251AliasWeightRedistributionAudit.lean:14:0: 'YangMills.RG.cmp89Eq251EuclideanNorm_rpow_mul_aliasWeight_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10405/10620] Built YangMills.RG.BalabanCMP99SourceFlatGeneratedQprimeTerminalOwner (15s)
# ✔ [10406/10620] Built YangMills.RG.BalabanCMP99SourceFlatWeightedAdjointScalarColumn (13s)
# ✔ [10407/10620] Built YangMills.RG.BalabanCMP99SourceFlatPhysicalComplexModeAction (20s)
# ✔ [10408/10620] Built YangMills.RG.FinitePiLpCanonicalComplexificationOuterTransport (22s)
# ✔ [10409/10620] Built YangMills.RG.BalabanCMP99SourceGeneratedPhysicalAmbientDictionary (63s)
# ✔ [10410/10620] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedAliasDenominator (7.3s)
# ✔ [10411/10620] Built YangMills.RG.BalabanCMP99SourceFlatQprimeAliasFibreDictionary (13s)
# ℹ [10412/10620] Built YangMills.RG.BalabanCMP89Eq251NoncentralRealIntegrandBoundAudit (11s)
# info: YangMills/RG/BalabanCMP89Eq251NoncentralRealIntegrandBoundAudit.lean:10:0: 'YangMills.RG.cmp89Eq251NoncentralRealIntegrand' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251NoncentralRealIntegrandBoundAudit.lean:11:0: 'YangMills.RG.cmp89Eq251NoncentralRealIntegrandConstant' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251NoncentralRealIntegrandBoundAudit.lean:12:0: 'YangMills.RG.sq_cmp89Eq251EuclideanNorm' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251NoncentralRealIntegrandBoundAudit.lean:13:0: 'YangMills.RG.cmp89Eq251NoncentralRealIntegrand_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10413/10620] Built YangMills.RG.BalabanCMP89Eq251CentralRealIntegrandBound (9.1s)
# ✔ [10414/10620] Built YangMills.RG.BalabanCMP85SourcePrefixGreen (25s)
# ✔ [10415/10620] Built YangMills.RG.BalabanCMP99SourceFlatPhysicalComplexWeightedAdjoint (13s)
# ✔ [10416/10620] Built YangMills.RG.BalabanCMP89Eq251FiniteRealIntegrandSum (7.4s)
# ✔ [10417/10620] Built YangMills.RG.BalabanCMP99SourceFlatGeneratedQprimeDirectOwnerKernel (17s)
# ✔ [10418/10620] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedRealLower (12s)
# ✔ [10419/10620] Built YangMills.RG.BalabanCMP99SourceSeparatedGeneratedPhysicalAmbientDictionary (16s)
# ℹ [10420/10623] Built YangMills.RG.BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit (97s)
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:22:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.total' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:23:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.residual' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:24:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.sourceRange_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:25:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.finiteRange' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:26:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.coercivity_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:27:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.K_coercive' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:28:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.K_comp_interactingCovariance' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:29:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.localizedRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:30:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.localizedRegion_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:31:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.localizedCoordinates_nonempty' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:32:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.conditionedRoot' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:33:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.conditionedCovariance_nondegenerate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:34:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.E0' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:35:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.threshold' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:36:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.alpha' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:37:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.rootBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:38:0: 'YangMills.RG.CMP116CenteredConditionedCombinedSourceData.volumeRate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq226CenteredConditionedCombinedSourcePreEq136Audit.lean:39:0: 'YangMills.RG.cmp116Eq226CenteredConditionedCombinedSourcePreEq136' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10421/10623] Built YangMills.RG.BalabanCMP99SourceFlatWeightedAdjointPhysicalColumn (11s)
# ℹ [10422/10623] Built YangMills.RG.BalabanCMP89Eq251FiniteRealIntegrandSumAudit (10s)
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:10:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandSum' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:11:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:12:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandSum_le_bound' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10423/10639] Built YangMills.RG.BalabanCMP89Eq251CentralRealIntegrandBoundAudit (16s)
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:10:0: 'YangMills.RG.cmp89Eq251CentralMomentumRadius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:11:0: 'YangMills.RG.cmp89Eq251CentralRealIntegrand' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:12:0: 'YangMills.RG.cmp89Eq251CentralRealIntegrandConstant' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:13:0: 'YangMills.RG.cmp89Eq251MomentumSquare_le_central_radius_sq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:14:0: 'YangMills.RG.cmp89Eq251EuclideanNorm_le_central_radius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:15:0: 'YangMills.RG.rpow_le_one_add_self_of_mem_Icc' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:16:0: 'YangMills.RG.cmp89Eq249_unit_div_scaled_central_alias_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:17:0: 'YangMills.RG.cmp89Eq251CentralRealIntegrand_le_constant' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10424/10639] Built YangMills.RG.BalabanCMP89Eq247EntireAliasTransposeSolution (9.0s)
# ✔ [10425/10647] Built YangMills.RG.BalabanCMP89MassZeroCentralFineSymbolNonvanishing (9.5s)
# ✔ [10426/10656] Built YangMills.RG.BalabanCMP89Eq249NoncentralRealGap (16s)
# ✔ [10427/10656] Built YangMills.RG.BalabanCMP99SourceFlatGeneratedTerminalBlockCollapse (18s)
# ✔ [10428/10667] Built YangMills.RG.BalabanCMP89Eq249StabilizedAliasTransposeSolution (8.6s)
# ✔ [10429/10667] Built YangMills.RG.BalabanCMP99SourceCoarseFibreFourierNeg (11s)
# ℹ [10430/10668] Built YangMills.RG.BalabanCMP85Eq221EffectiveQuadratic (39s)
# info: YangMills/RG/BalabanCMP85Eq221EffectiveQuadratic.lean:213:2: Try this:
#   [apply] ring_nf
#
#   The `ring` tactic failed to close the goal. Use `ring_nf` to obtain a normal form.
#
#   Note that `ring` works primarily in *commutative* rings. If you have a noncommutative ring, abelian group or module, consider using `noncomm_ring`, `abel` or `module` instead.
# ✔ [10431/10668] Built YangMills.RG.BalabanCMP99SourceFlatGeneratedPrecisionScalarDictionary (12s)
# ✔ [10432/10671] Built YangMills.RG.BalabanCMP99FlatComplexFibrePointSourceFourierReconstruction (13s)
# ✔ [10433/10672] Built YangMills.RG.BalabanCMP89Eq249NoncentralComplexGap (18s)
# ℹ [10434/10694] Built YangMills.RG.BalabanCMP99SourceCoarseFibreFourierNegQuotientCarry (13s)
# info: YangMills/RG/BalabanCMP99SourceCoarseFibreFourierNegQuotientCarry.lean:77:46: Try this:
#   [apply] ring_nf
#
#   The `ring` tactic failed to close the goal. Use `ring_nf` to obtain a normal form.
#
#   Note that `ring` works primarily in *commutative* rings. If you have a noncommutative ring, abelian group or module, consider using `noncomm_ring`, `abel` or `module` instead.
# ✔ [10435/10700] Built YangMills.RG.BalabanCMP99SourceGeneratedFlatPhysicalPrecisionKernel (46s)
# ✔ [10436/10701] Built YangMills.RG.BalabanCMP89CenteredUnitCubeTorusQuotient (8.0s)
# ✔ [10437/10702] Built YangMills.RG.BalabanCMP99FlatFiniteGridAliasing (13s)
# ✔ [10438/10703] Built YangMills.RG.BalabanCMP89CenteredPeriodicL1ResidueSum (11s)
# ✔ [10439/10704] Built YangMills.RG.BalabanCMP89Eq249UniformNoncentralComplexRadius (15s)
# ℹ [10440/10704] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit (8.8s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:5:0: 'YangMills.RG.cmp89Eq249ZeroAlias_mem' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:6:0: 'YangMills.RG.cmp89Eq247ComplexReducedAliasDenominator_eq_central_add_noncentral' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:7:0: 'YangMills.RG.cmp89Eq249CentralFine_mul_reduced_eq_stabilized' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10441/10705] Built YangMills.RG.BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:5:0: 'YangMills.RG.cmp89Eq246EntireAliasPrecisionMatrix_mulVec' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:6:0: 'YangMills.RG.differentiable_cmp89Eq246EntireAliasPrecisionMatrix_entry' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:7:0: 'YangMills.RG.cmp89Eq246EntireAliasAverageRow_ofReal_eq_conj' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:8:0: 'YangMills.RG.cmp89Eq246EntireAliasFineSymbol_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10442/10705] Built YangMills.RG.BalabanCMP89Eq245EntireAverageStripGrowthAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_le_exp' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_le_exp' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_le_exp_pow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_mul_neg_le_exp_pow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10443/10706] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientBound (15s)
# ✔ [10444/10707] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBound (16s)
# ℹ [10445/10707] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedRealLowerAudit (27s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:5:0: 'YangMills.RG.cmp89Eq249ComplexNoncentralAliasSum_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:6:0: 'YangMills.RG.cmp89Eq249CentralEntireAveragePair_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:7:0: 'YangMills.RG.cmp89Eq249CentralStabilizedAliasDenominator_ofReal_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:8:0: 'YangMills.RG.cmp89Eq249RealNoncentralAliasSum_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:9:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_real' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:10:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_re' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:11:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_mono' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:12:0: 'YangMills.RG.cmp85Eq215Floor_le_cmp89Eq249CentralStabilizedAliasDenominator_re' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10446/10707] Built YangMills.RG.BalabanCMP89Eq245EntireAverageVerticalVariationAudit (9.0s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:3:0: 'YangMills.RG.cmp89Eq245EntireAverageBase_pow_eq_exp_modeExponent' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageModeExponent_sub_realSlice_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:5:0: 'YangMills.RG.norm_complex_exp_sub_exp_le_of_norm_sub_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10447/10708] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit (8.1s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:3:0: 'YangMills.RG.norm_fin_prod_sub_prod_le_card_mul' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:5:0: 'YangMills.RG.cmp89Eq245ComplexMomentumRealSlice_neg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_pair_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10448/10708] Built YangMills.RG.BalabanCMP85Eq230CoarseCovariance (50s)
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:75:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp85SourceStepWeightedAdjoint_pairing`:
#   [NeZero M]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero M] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:98:22: This simp argument is unused:
#   conj_trivial
#
# Hint: Omit it from the simp argument list.
#   simp only [mul_pow,̵ ̵c̵o̵n̵j̵_̵t̵r̵i̵v̵i̵a̵l̵]
#
# Note: This linter can be disabled with `set_option linter.unusedSimpArgs false`
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:104:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp85SourceStepWeightedTerm_eq_counting`:
#   [NeZero M]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero M] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [10449/10709] Built YangMills.RG.BalabanCMP89Eq249NoncentralRealGapAudit (28s)
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:5:0: 'YangMills.RG.one_div_nine_le_cmp89Eq245ScaledLaplacianSymbol_noncentral_alias' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:6:0: 'YangMills.RG.cmp89Eq245ScaledLaplacianSymbol_noncentral_alias_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:7:0: 'YangMills.RG.cmp89Eq250AliasDenominatorSummand_noncentral_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:8:0: 'YangMills.RG.cmp89Eq249RealNoncentralAliasSum_nonneg_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:9:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_real_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:10:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_re_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:11:0: 'YangMills.RG.cmp85Eq215Floor_le_cmp89Eq249CentralStabilizedAliasDenominator_re_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10450/10709] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariation (13s)
# ✔ [10451/10710] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumBound (11s)
# ℹ [10452/10710] Built YangMills.RG.BalabanCMP89Eq245EntireLaplacianVariationAudit (10s)
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifferenceExponent_sub_realSlice_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_ofReal_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:6:0: 'YangMills.RG.norm_mul_sub_mul_le_eps_mul_two_mul_add' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_pair_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:8:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledLaplacianSymbol_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10453/10711] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSum (10s)
# ℹ [10454/10712] Built YangMills.RG.BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit.lean:3:0: 'YangMills.RG.cmp89Eq249NoncentralComplexGapBudget_le_of_uniformRadiusCondition' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit.lean:4:0: 'YangMills.RG.half_momentum_gap_le_norm_cmp89Eq245EntireScaledLaplacianSymbol_of_uniformRadius' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10455/10713] Built YangMills.RG.BalabanCMP89Eq249NoncentralComplexGapAudit (15s)
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:3:0: 'YangMills.RG.sum_abs_le_two_mul_cmp89Eq251EuclideanNorm_fin_four' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:4:0: 'YangMills.RG.cmp89Eq245EntireScaledLaplacianVerticalBudget_le_noncentralGapBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:5:0: 'YangMills.RG.half_real_gap_le_norm_of_norm_sub_le_half' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:6:0: 'YangMills.RG.half_momentum_gap_le_norm_cmp89Eq245EntireScaledLaplacianSymbol' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledLaplacianSymbol_noncentral_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10456/10714] Built YangMills.RG.BalabanCMP85ScalarRecurrence (11s)
# ℹ [10457/10715] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAliasStripBoundAudit (17s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_sub_one_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:5:0: 'YangMills.RG.cmp89Eq245EntireAverageFactor_eq_geometricQuotient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:6:0: 'YangMills.RG.one_div_three_pi_mul_abs_le_norm_cmp89Eq245EntireAverageBase_sub_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:7:0: 'YangMills.RG.one_div_six_pi_mul_abs_le_norm_cmp89Eq245EntireAverageBase_sub_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:8:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:9:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10458/10722] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumBoundAudit (11s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq249ComplexNoncentralAliasSum_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10459/10723] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit (16s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAveragePair_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_le_radialWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10460/10728] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit (13s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_scaled_alias_le_of_zone' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:4:0: 'YangMills.RG.cmp89Eq251MultidimensionalAliasWeight_neg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_neg_realSlice_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAveragePair_alias_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10461/10730] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumVariation (22s)
# ℹ [10462/10730] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:3:0: 'YangMills.RG.norm_div_sub_div_le_of_lower_bounds' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:4:0: 'YangMills.RG.cmp89Eq248EntireAliasMomentum_realSlice_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_sub_realSlice_le_radial' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10463/10734] Built YangMills.RG.PeriodicHolomorphicVerticalShiftAudit (9.3s)
# info: YangMills/RG/PeriodicHolomorphicVerticalShiftAudit.lean:5:0: 'YangMills.RG.intervalIntegral_eq_verticalShift_of_periodic_of_differentiableOn' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10464/10745] Built YangMills.RG.HolomorphicVerticalShiftBoundaryAudit (8.8s)
# info: YangMills/RG/HolomorphicVerticalShiftBoundaryAudit.lean:16:0: 'YangMills.RG.intervalIntegral_eq_verticalShift_of_boundary_eq_of_differentiableOn' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10465/10747] Built YangMills.RG.IntervalIntegralSliceTransportAudit (7.7s)
# info: YangMills/RG/IntervalIntegralSliceTransportAudit.lean:3:0: 'YangMills.RG.intervalIntegral_integral_eq_of_slice_intervalIntegral_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10466/10748] Built YangMills.RG.BalabanCMP85BlockGaussianAlgebra (13s)
# ℹ [10467/10748] Built YangMills.RG.BalabanCMP89Eq251EntireScaledDifferenceStripUpperAudit (6.6s)
# info: YangMills/RG/BalabanCMP89Eq251EntireScaledDifferenceStripUpperAudit.lean:12:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_le_abs_re_add_vertical' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10468/10763] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit (14s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_sub_realSlice_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq249ComplexNoncentralAliasSum_sub_realSlice_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10469/10765] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedDenominatorVariation (14s)
# ℹ [10470/10766] Built YangMills.RG.IntervalIntegralPiCoordinateTransportAudit (10s)
# info: YangMills/RG/IntervalIntegralPiCoordinateTransportAudit.lean:3:0: 'YangMills.RG.intervalIntegral_integral_eq_of_slice_intervalIntegral_ae_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/IntervalIntegralPiCoordinateTransportAudit.lean:4:0: 'YangMills.RG.integral_pi_restrict_uIoc_eq_of_coordinate_intervalIntegral_ae_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10471/10766] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit (13s)
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:11:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientSum' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:12:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientSumBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:13:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotientSum_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10472/10766] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit (16s)
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:11:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointRadialConstant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:12:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientConstant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:13:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_alias_le_two_euclidean' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:14:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotient_le_radialWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:15:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotient_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10473/10767] Built YangMills.RG.BalabanCMP89Eq251StabilizedEndpointCentralFineUpper (10s)
# ✔ [10474/10767] Built YangMills.RG.BalabanCMP85TypedSchurBrackets (19s)
# ℹ [10475/10769] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit (16s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:3:0: 'YangMills.RG.cmp89Eq245EntireScaledLaplacianVerticalBudget_le_centralBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq249CentralEntireFineSymbol_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq249CentralStabilizedAliasDenominator_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10476/10784] Built YangMills.RG.BalabanCMP99FlatFiniteGridAliasingAudit (17s)
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:3:0: 'YangMills.RG.cmp99FlatIntegerResidue' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:4:0: 'YangMills.RG.CMP99FlatIntegerResidueClass' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:5:0: 'YangMills.RG.norm_cmp99FlatZModFourierCharacter' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:6:0: 'YangMills.RG.cmp99Flat_normalizedCharacterAverage_integerResidue' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:7:0: 'YangMills.RG.summable_cmp99FlatZModFourierCharacter_mul_integerCoefficient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:8:0: 'YangMills.RG.cmp99FlatFiniteGridFourierSeriesSample' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:9:0: 'YangMills.RG.cmp99Flat_normalizedFiniteGridFourierSeriesSample_eq_residueClass' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10477/10785] Built YangMills.RG.BalabanCMP89CenteredBrillouinAffineSlice (8.1s)
# ✔ [10478/10787] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedComplexFloor (12s)
# ℹ [10479/10787] Built YangMills.RG.BalabanCMP89CenteredBrillouinAffineSliceAudit (12s)
# info: YangMills/RG/BalabanCMP89CenteredBrillouinAffineSliceAudit.lean:6:0: 'YangMills.RG.cmp89CenteredBrillouin_affineSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredBrillouinAffineSliceAudit.lean:7:0: 'YangMills.RG.cmp89CenteredBrillouin_affineSlice_complex' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10480/10787] Built YangMills.RG.BalabanCMP89Eq251StabilizedEndpointCentralFineUpperAudit (15s)
# info: YangMills/RG/BalabanCMP89Eq251StabilizedEndpointCentralFineUpperAudit.lean:12:0: 'YangMills.RG.cmp89Eq251CentralFineSymbolStripUpperBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251StabilizedEndpointCentralFineUpperAudit.lean:13:0: 'YangMills.RG.norm_cmp89Eq249CentralEntireFineSymbol_le_stripUpperBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10481/10789] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedComplexFloorAudit (22s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedComplexFloorAudit.lean:3:0: 'YangMills.RG.sub_variation_le_norm_cmp89Eq249CentralStabilizedAliasDenominator' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedComplexFloorAudit.lean:4:0: 'YangMills.RG.cmp89Eq249CentralStabilizedAliasDenominator_ne_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedComplexFloorAudit.lean:5:0: 'YangMills.RG.norm_inv_cmp89Eq249CentralStabilizedAliasDenominator_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10482/10802] Built YangMills.RG.BalabanCMP89CenteredUnitCubeTorusQuotientAudit (30s)
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:6:0: 'YangMills.RG.CMP89CenteredUnitInterval' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:7:0: 'YangMills.RG.CMP89CenteredUnitCube' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:8:0: 'YangMills.RG.cmp89CenteredUnitLeft' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:9:0: 'YangMills.RG.cmp89CenteredUnitRight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:10:0: 'YangMills.RG.cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:11:0: 'YangMills.RG.cmp89CenteredUnitInterval_eq_or_oppositeEndpoints' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:12:0: 'YangMills.RG.cmp89CenteredUnitCubeReplace' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:13:0: 'YangMills.RG.cmp89CenteredUnitCube_update_eq_of_faceSeam' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:14:0: 'YangMills.RG.cmp89CenteredUnitCube_factorsThrough_of_faceSeam' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:15:0: 'YangMills.RG.continuous_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:16:0: 'YangMills.RG.surjective_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:17:0: 'YangMills.RG.isQuotientMap_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:18:0: 'YangMills.RG.cmp89CenteredUnitCubeCovering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:19:0: 'YangMills.RG.isQuotientMap_cmp89CenteredUnitCubeCovering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:20:0: 'YangMills.RG.cmp89CenteredUnitCubeLift' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:21:0: 'YangMills.RG.cmp89CenteredUnitCubeLift_comp_covering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:22:0: 'YangMills.RG.cmp89CenteredUnitRealCubeMeasure' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:23:0: 'YangMills.RG.cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:24:0: 'YangMills.RG.measurePreserving_cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:25:0: 'YangMills.RG.integral_cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10483/10819] Built YangMills.RG.BalabanCMP89CenteredPeriodicL1ResidueSumAudit (26s)
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:7:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:8:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:9:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_neg_neg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:10:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_nat_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:11:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_neg_add_one_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:12:0: 'YangMills.RG.summable_cmp89CenteredPeriodicOneDimensionalExpWeight_of_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:13:0: 'YangMills.RG.summable_cmp89CenteredPeriodicOneDimensionalExpWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:14:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicOneDimensionalExpWeight_le_of_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:15:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicOneDimensionalExpWeight_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:16:0: 'YangMills.RG.cmp89CenteredPeriodicL1ResidueWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:17:0: 'YangMills.RG.cmp89CenteredPeriodicL1ResidueWeight_eq_signedLatticeWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:18:0: 'YangMills.RG.summable_pi_int_prod_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:19:0: 'YangMills.RG.tsum_pi_int_prod_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:20:0: 'YangMills.RG.summable_cmp89CenteredPeriodicL1ResidueWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:21:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:22:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_physical_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:23:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_physical_uniform_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10484/10820] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedComplexFloorMassUniform (16s)
# ✔ [10485/10821] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedComplexRadius (19s)
# ℹ [10486/10821] Built YangMills.RG.BalabanCMP85BlockGaussianAlgebraAudit (14s)
# info: YangMills/RG/BalabanCMP85BlockGaussianAlgebraAudit.lean:12:0: 'YangMills.RG.cmp85_rightSchurBracket_eq_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP85BlockGaussianAlgebraAudit.lean:13:0: 'YangMills.RG.cmp85_leftSchurBracket_eq_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10487/10821] Built YangMills.RG.BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit (20s)
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:3:0: 'YangMills.RG.cmp99FlatComplexFibrePointSource' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:4:0: 'YangMills.RG.sum_cmp99FlatFourierMode_mul_inv' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:5:0: 'YangMills.RG.cmp99FlatComplexFibrePointSource_eq_normalized_sum_fourierMode' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:6:0: 'YangMills.RG.ContinuousLinearMap_apply_cmp99FlatComplexFibrePointSource_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10488/10823] Built YangMills.RG.BalabanCMP85TypedGreenInverse (48s)
# ℹ [10489/10823] Built YangMills.RG.BalabanCMP99SourcePrefixPoincareAudit (27s)
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:7:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_le_succ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:8:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_monotone' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:9:0: 'YangMills.RG.cmp99SourcePoincareErrorCoeff_le_succ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:10:0: 'YangMills.RG.cmp99SourcePoincareErrorCoeff_monotone' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:11:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_pos' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:12:0: 'YangMills.RG.cmp99OneScaleBlockPoincareConstant_pow_pos' depends on axioms: [propext, Classical.choice, Quot.sound]
# ...
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLaplacianOwnerDecayAudit.lean:5:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefixLaplacian_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11075/11099] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixEq342Certificate (8.3s)
# ✔ [11076/11099] Built YangMills.RG.BalabanCMP99SourceEq395RegionalMiddleCommutatorDecay (43s)
# ℹ [11077/11099] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit (15s)
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:7:0: 'YangMills.RG.cmp99ActiveRegionSourceCovariantD0CLM_adjoint_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:8:0: 'YangMills.RG.finitePiLpSupNorm_cmp99ActiveRegionSourceCovariantD0CLM_adjoint_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:9:0: 'YangMills.RG.cmp99ActiveRegionSourceCovariantD0CLM_adjoint_apply_eq_zero_of_owner_far' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:10:0: 'YangMills.RG.finitePiLpTypedBlockLocalizedSupBound_comp_of_ownerKernel' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:11:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefixRightAdjoint_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11078/11099] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixEq342CertificateAudit (10s)
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixEq342CertificateAudit.lean:12:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefix_eq342SourceLocalizedGreenCertificate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11079/11099] Built YangMills.RG.BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit (22s)
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceMiddleAmbient_eq_extend_onSource' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceMiddleAmbient_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalMiddle_smoothCommutator_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedLeftDefect_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11080/11099] Built YangMills.RG.BalabanCMP99SourceEq395RegionalCovarianceDecay (24s)
# ✔ [11081/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedRAtomDecay (9.7s)
# ℹ [11082/11099] Built YangMills.RG.BalabanCMP99SourceEq395RegionalCovarianceDecayAudit (13s)
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalCovarianceDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceCoordinates_eq_onSource' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalCovarianceDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceAmbient_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11083/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedRAtomDecayAudit (11s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomInputRate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomDecayRate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomDecayAmplitude' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtom_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11084/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedCorrectionDecay (22s)
# ℹ [11085/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedCorrectionDecayAudit (18s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_grouped_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.norm_cmp99Eq395PhysicalCorrection_le_groupedSchurAmplitude' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGlobalMiddle_comp_correctedCovariance_eq_id_of_groupedSchurSmall' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11086/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedNeumannDecay (23s)
# ✔ [11087/11099] Built YangMills.RG.BalabanCMP99SourceEq395PatchedCovarianceDecay (10s)
# ℹ [11088/11099] Built YangMills.RG.BalabanCMP99SourceEq395GroupedNeumannDecayAudit (23s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_grouped_weightedRow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.norm_cmp99Eq395PhysicalCorrection_le_groupedNeumannRatio' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_pow_grouped_weightedRow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_tsum_pow_grouped_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11089/11099] Built YangMills.RG.BalabanCMP99SourceEq395CanonicalCovariance (13s)
# ℹ [11090/11099] Built YangMills.RG.BalabanCMP99SourceEq395PatchedCovarianceDecayAudit (15s)
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:3:0: 'YangMills.RG.cmp99SourceSquarePartition_sum_norm_mul_norm_le_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:4:0: 'YangMills.RG.finitePiLpExponentialKernelBound_squarePartition_sum' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalPatchedCovariance_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrectedCovariance_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11091/11099] Built YangMills.RG.BalabanCMP99SourceEq395CanonicalCovarianceAudit (22s)
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCanonicalCovariance' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395FullCoarseRegion_extendZero_comp_restrict_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395GeneratedPhysicalCovarianceOnSource_comp_middle' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCanonicalCovariance_comp_globalMiddle_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:7:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrectedCovariance_eq_canonical' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11092/11099] Built YangMills.RG.BalabanCMP99SourceEq3163Hprime (62s)
# ℹ [11093/11099] Built YangMills.RG.BalabanCMP99SourceEq3163HprimeAudit (13s)
# info: YangMills/RG/BalabanCMP99SourceEq3163HprimeAudit.lean:3:0: 'YangMills.RG.cmp99SourceEq3163PhysicalHprime' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq3163HprimeAudit.lean:4:0: 'YangMills.RG.cmp99SourceEq3163_Qprime_comp_physicalHprime_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11094/11099] Built YangMills.RG.BalabanCMP99SourceEq325GaugeProjection (25s)
# ✔ [11095/11099] Built YangMills.RG.BalabanCMP99SourceEq326ProjectedGaugeMass (23s)
# ℹ [11096/11099] Built YangMills.RG.BalabanCMP99SourceEq325GaugeProjectionAudit (36s)
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:3:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:4:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:5:0: 'YangMills.RG.cmp99Eq325Complement_comp_self_of_middle_comp_inverse' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:6:0: 'YangMills.RG.cmp99Eq325Projection_comp_self_of_complement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:7:0: 'YangMills.RG.cmp99Eq325_QG_comp_projection_eq_zero_of_middle_comp_inverse' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:8:0: 'YangMills.RG.cmp99Eq325Complement_isSymmetric_of_weightedAdjoint' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:9:0: 'YangMills.RG.cmp99Eq325Projection_isSymmetric_of_complement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:10:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement_comp_self' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:11:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection_comp_self' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:12:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement_isSymmetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:13:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection_isSymmetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:14:0: 'YangMills.RG.cmp99SourceEq325_Qprime_comp_green_comp_projection_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11097/11099] Built YangMills.RG.BalabanCMP99SourceEq326ProjectedGaugeMassAudit (25s)
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:3:0: 'YangMills.RG.cmp99ProjectedGaugeMassCLM' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:4:0: 'YangMills.RG.inner_cmp99ProjectedGaugeMassCLM_eq_norm_sq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:5:0: 'YangMills.RG.inner_cmp99ProjectedGaugeMassCLM_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:6:0: 'YangMills.RG.cmp99ProjectedGaugeMassCLM_isSymmetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:7:0: 'YangMills.RG.cmp99SourceEq326ProjectedGaugeMass' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:8:0: 'YangMills.RG.inner_cmp99SourceEq326ProjectedGaugeMass_eq_norm_sq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:9:0: 'YangMills.RG.inner_cmp99SourceEq326ProjectedGaugeMass_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:10:0: 'YangMills.RG.cmp99SourceEq326ProjectedGaugeMass_isSymmetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# Some required targets logged failures:
# - YangMills.RG.BalabanCMP99SourceActiveRegionFullCompanionPrecisionDecay
# - YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientMetric
# error: build failed
#
# STAGE=02_finite_pilp_distance_rescaling_yang_mills_core_root EXIT=1 SECONDS=11260.141
# ERROR=RuntimeError('FIRST_ERROR=02_finite_pilp_distance_rescaling_yang_mills_core_root')
# EVIDENCE_SHA256=7753e5a156c09ce8ed405c4b8e31cc0cfb8898ca0deadad66492c5e31530456c
# EVIDENCE_ARCHIVE=/content/hrpoly-finite-pilp-distance-rescaling-evidence.tar.gz
# EVIDENCE_ARCHIVE_SHA256=8bdd16ef32be62a61b82a8a90d266b641a4f169c8d95143694f2f8d0a508cd68
# FINAL_STATUS=FAIL
# RUNTIME_UNASSIGN_DEFERRED_TO_LAUNCHER=1
# RUNTIME_UNASSIGN_REQUESTED=1
# Traceback (most recent call last):
#   File "/content/colab_qprime_row_validation.py", line 261, in main
#     output = run(stage, command, cwd=ROOT)
#   File "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/a297c71b27d20de6980edc406e38c59074053dae/scripts/colab_finite_pilp_distance_rescaling_validation.py", line 82, in streaming_run
# RuntimeError: FIRST_ERROR=02_finite_pilp_distance_rescaling_yang_mills_core_root
# EVIDENCE_DOWNLOAD_REQUESTED=1
# LAUNCHER_EXIT=1
# RUNTIME_RETAINED_FOR_DEBUG=1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1980/1767248536.py in <cell line: 0>()
#      26         print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
#      27 if launcher_exit != 0:
# ---> 28     raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
#
# RuntimeError: RUNNER_EXIT=1
