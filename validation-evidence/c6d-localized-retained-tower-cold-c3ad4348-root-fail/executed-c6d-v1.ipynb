# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/e93015351f7022c345ff651e7334d9531ed5ff11/scripts/colab_c6d_localized_retained_tower_cold_validation.py"
RUNNER_SHA256 = "54cf917bfe803bda468d31e10297cd95665e992745a1e4f99e12722e8868cff2"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
release_runtime = runtime.unassign
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    if launcher_exit == 0:
        release_runtime()
    else:
        print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:5:0: 'YangMills.RG.cmp116Eq142PhysicalPotentialTerm_eq_cmp102Eq80FineHeadTailDomainFTCContribution' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:7:0: 'YangMills.RG.cmp116Eq214PhysicalComplexTauPotential_cmp102FineHeadTail_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:9:0: 'YangMills.RG.cmp116Eq214ComplexTauPotentialCoordinate_cmp102FineHeadTail_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:11:0: 'YangMills.RG.CMP116Eq214PhysicalContourDensity.withCMP102FineHeadTailPotential' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:13:0: 'YangMills.RG.CMP116Eq214PhysicalContourDensity.withCMP102FineHeadTailPotential_potential' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailPotentialAudit.lean:15:0: 'YangMills.RG.CMP116Eq214PhysicalContourDensity.withCMP102FineHeadTailPotential_potential_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10205/10264] Built YangMills.RG.BalabanCMP109Lemma1PhysicalBackgroundsAudit (57s)
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:3:0: 'YangMills.RG.cmp109Eq212PerturbedCoarseBackground' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:4:0: 'YangMills.RG.cmp109Eq212BaseFineBackground' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:5:0: 'YangMills.RG.cmp109Eq212PerturbedFineBackground' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:6:0: 'YangMills.RG.blockMap_cmp109Eq212BaseFineBackground' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:7:0: 'YangMills.RG.blockMap_cmp109Eq212PerturbedFineBackground' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:8:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:9:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference_eq_sum_changed' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:10:0: 'YangMills.RG.norm_cmp109Eq212Lemma1EnergyDifference_le_sum_changed' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1PhysicalBackgroundsAudit.lean:11:0: 'YangMills.RG.exists_cmp109Eq212Lemma1PhysicalBackgrounds' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10206/10267] Built YangMills.RG.BalabanCMP109Lemma1NativeRootedResidual (24s)
# ℹ [10207/10267] Built YangMills.RG.BalabanCMP109Lemma1ResidualFamilyAudit (44s)
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:3:0: 'YangMills.RG.cmp109Eq212Lemma1LocalizedDifference' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:4:0: 'YangMills.RG.cmp109Eq212Lemma1AffectedDomainFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:5:0: 'YangMills.RG.cmp109Eq212Lemma1ResidualActivity' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:6:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference_eq_sum_residualActivity' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:7:0: 'YangMills.RG.cmp109Eq212Lemma1ResidualActivity_eq_zero_of_not_mem' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1ResidualFamilyAudit.lean:8:0: 'YangMills.RG.norm_cmp109Eq212Lemma1ResidualActivity_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# ⚠ [10208/10269] Built YangMills.RG.BalabanCMP109Lemma1CombinedCenteredRegion (17s)
# warning: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegion.lean:175:5: unused variable `Dict`
#
# Note: This linter can be disabled with `set_option linter.unusedVariables false`
# ✔ [10209/10269] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBound (97s)
# ℹ [10210/10271] Built YangMills.RG.BalabanCMP116Eq214CMP102FineHeadTailTaylorSplitAudit (41s)
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailTaylorSplitAudit.lean:3:0: 'YangMills.RG.cmp102Eq80PhysicalFineHeadTailDomainFixedQuadraticFamily' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailTaylorSplitAudit.lean:5:0: 'YangMills.RG.cmp102Eq80PhysicalFineHeadTailDomainTaylorResidualFamily' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailTaylorSplitAudit.lean:7:0: 'YangMills.RG.cmp102Eq80PhysicalFineHeadTailDomainTaylorResidualFamily_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq214CMP102FineHeadTailTaylorSplitAudit.lean:9:0: 'YangMills.RG.cmp116Eq142PhysicalPotentialTerm_fixedTaylorSplit_eq_cmp102Eq80FineHeadTailDomainFTCContribution' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10211/10271] Built YangMills.RG.BalabanCMP109Lemma1NativeRootedResidualAudit (26s)
# info: YangMills/RG/BalabanCMP109Lemma1NativeRootedResidualAudit.lean:3:0: 'YangMills.RG.cmp109Lemma1NativeRootBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1NativeRootedResidualAudit.lean:4:0: 'YangMills.RG.cmp109Lemma1NativeRootBound_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1NativeRootedResidualAudit.lean:5:0: 'YangMills.RG.cmp109Lemma1NativeIndexed_rooted_residual_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10212/10271] Built YangMills.RG.BalabanCMP109Lemma1Eq136SourceCertificateAudit (37s)
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:3:0: 'YangMills.RG.cmp109Lemma1SourceSmallField' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:4:0: 'YangMills.RG.cmp109Lemma1SourceBondSupport' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:5:0: 'YangMills.RG.mem_cmp109Lemma1SourceBondSupport_iff' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:6:0: 'YangMills.RG.cmp109Lemma1SourceResidual' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:7:0: 'YangMills.RG.CMP109Lemma1Eq136SourceCertificate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1Eq136SourceCertificateAudit.lean:8:0: 'YangMills.RG.CMP109Lemma1Eq136SourceCertificate.toNativeCertificate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10213/10273] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedDomainDictionary (27s)
# ℹ [10214/10273] Built YangMills.RG.BalabanCMP109Lemma1CoarsenedResidualFamilyAudit (59s)
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:3:0: 'YangMills.RG.cmp109Lemma1CoarsenedBlocks' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:4:0: 'YangMills.RG.cmp109Lemma1CoarsenedBlocks_nonempty' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:5:0: 'YangMills.RG.cmp109Lemma1NativeDomainFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:6:0: 'YangMills.RG.cmp109Lemma1NativeBlockFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:7:0: 'YangMills.RG.cmp109Lemma1NativeDomain_blocks_injective' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:8:0: 'YangMills.RG.cmp109Lemma1NativeBlockFamily_connected' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:9:0: 'YangMills.RG.cmp109Lemma1NativeBlockFamily_coarsenedRoot_sum_pow_card_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:10:0: 'YangMills.RG.cmp109Lemma1NativeDomainFamily_coarsenedRoot_sum_pow_card_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:11:0: 'YangMills.RG.exp_neg_cmp109Lemma1NativeMetric_le_cardWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:12:0: 'YangMills.RG.cmp109Lemma1NativeDomainFamily_coarsenedRoot_exp_metric_sum_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:13:0: 'YangMills.RG.cmp109Lemma1NativeDomainFamily_coarsenedRoot_weighted_exp_metric_sum_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:14:0: 'YangMills.RG.cmp109Lemma1NativeDomainAt' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:15:0: 'YangMills.RG.cmp109Lemma1NativeDomainAt_mem' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:16:0: 'YangMills.RG.cmp109Lemma1NativeDomainAt_injective' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:17:0: 'YangMills.RG.image_cmp109Lemma1NativeDomainAt_univ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:18:0: 'YangMills.RG.sum_cmp109Lemma1NativeDomainAt_eq_sum_nativeDomainFamily' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:19:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainMetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:20:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainCard' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:21:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainSupport' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:22:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainSupport_nonempty' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:23:0: 'YangMills.RG.sum_cmp109Lemma1NativeDomainAt_filter_support_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:24:0: 'YangMills.RG.cmp109Lemma1CoarsenedBlockFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:25:0: 'YangMills.RG.cmp109Eq212Lemma1CoarsenedResidualActivity' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:26:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference_eq_sum_nativeResidualActivity' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:27:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference_eq_sum_indexedNativeResidualActivity' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CoarsenedResidualFamilyAudit.lean:28:0: 'YangMills.RG.cmp109Eq212Lemma1EnergyDifference_eq_sum_coarsenedResidualActivity' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10215/10275] Built YangMills.RG.BalabanCMP102Eq80SourcePi4RootedResidual (36s)
# ✔ [10216/10277] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetric (28s)
# ℹ [10217/10277] Built YangMills.RG.BalabanCMP109Lemma1CombinedCenteredRegionAudit (30s)
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:3:0: 'YangMills.RG.cmp116LocalizationCore_mono_for_combinedRegion' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:4:0: 'YangMills.RG.cmp109Lemma1NativeCoarsenedSupportFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:5:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainSupport_mem_supportFamily' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:6:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedBlockDomainFamily' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:7:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedCenteredRegion' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:8:0: 'YangMills.RG.cmp102Eq80SourcePi4CenteredRegion_subset_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:9:0: 'YangMills.RG.cmp109Lemma1NativeIndexedDomainSupport_subset_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:10:0: 'YangMills.RG.cmp102Eq80SourcePi4IndexedLocalizationDomain_bondSupport_subset_combinedRegionInterior' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP109Lemma1CombinedCenteredRegionAudit.lean:11:0: 'YangMills.RG.physicalBondProjection_indexedSourceDomain_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10218/10279] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedQuadraticCore (15s)
# ✔ [10219/10279] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedRootedResidual (15s)
# ℹ [10220/10281] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit (23s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:3:0: 'YangMills.RG.CMP116Eq80Lemma1CombinedDomainCount' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:4:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainSupport' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:5:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainMetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:6:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainCard' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:7:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainSupport_direct' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:8:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainSupport_native' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:9:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainMetric_direct' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:10:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainMetric_native' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:11:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainCard_direct' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:12:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainCard_native' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:13:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainMetric_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:14:0: 'YangMills.RG.cmp102Eq80SourcePi4IndexedDomainBlocks_subset_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:15:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainSupport_nonempty' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedDomainDictionaryAudit.lean:16:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedDomainSupport_subset_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10221/10283] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBoundAudit (32s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp102AffinePropagatorJetFTCSecondFieldDerivative_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBoundAudit.lean:5:0: 'YangMills.RG.cmp102Eq80PhysicalDomainFTCSecondFieldSourceMetricMajorant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBoundAudit.lean:7:0: 'YangMills.RG.norm_cmp102Eq80PhysicalFineHeadTailDomainFTCContributionSecondFieldDerivative_le_sourceMetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCSecondFieldSourceMetricBoundAudit.lean:9:0: 'YangMills.RG.abs_inner_cmp102Eq80PhysicalFineHeadTailDomainFTCRadialOperator_le_sourceMetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10222/10285] Built YangMills.RG.BalabanCMP116QuadraticCoreHessian (15s)
# warning: YangMills/RG/BalabanCMP116QuadraticCoreHessian.lean:99:28: try 'simp' instead of 'simpa'
#
# Note: This linter can be disabled with `set_option linter.unnecessarySimpa false`
# ℹ [10223/10285] Built YangMills.RG.BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit (23s)
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit.lean:3:0: 'YangMills.RG.cmp102Eq80Eq143CardRate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit.lean:4:0: 'YangMills.RG.cmp102Eq80Eq143MetricRate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit.lean:5:0: 'YangMills.RG.cmp102Eq80Eq143ProducerPrefactor' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit.lean:6:0: 'YangMills.RG.CMP102Eq80Eq143ProducerBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80PhysicalDomainFTCEq143SourceMetricAudit.lean:7:0: 'YangMills.RG.cmp102Eq80PhysicalDomainFTCSecondFieldSourceMetricMajorant_le_eq143' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10224/10295] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit (21s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:3:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedTotal' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:4:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedResidual' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:5:0: 'YangMills.RG.sum_cmp116Eq80Lemma1CombinedTotal' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:6:0: 'YangMills.RG.sum_cmp116Eq80Lemma1CombinedResidual' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:7:0: 'YangMills.RG.cmp116Eq142PhysicalQuadraticCore_combined_direct' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:8:0: 'YangMills.RG.cmp116Eq142PhysicalQuadraticCore_combined_native' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:9:0: 'YangMills.RG.contDiff_cmp116Eq142PhysicalQuadraticCore_combined' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedQuadraticCoreAudit.lean:10:0: 'YangMills.RG.abs_cmp116FDerivHessian_combined_le_eq143' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10225/10295] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedCutoffCarrier (17s)
# ✔ [10226/10296] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedVolumeBudget (20s)
# ℹ [10227/10299] Built YangMills.RG.BalabanCMP116QuadraticCoreHessianAudit (18s)
# info: YangMills/RG/BalabanCMP116QuadraticCoreHessianAudit.lean:3:0: 'YangMills.RG.cmp116FDerivHessian_half_bilinearDiagonal' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116QuadraticCoreHessianAudit.lean:4:0: 'YangMills.RG.abs_cmp116FDerivHessian_half_bilinearDiagonal_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116QuadraticCoreHessianAudit.lean:5:0: 'YangMills.RG.abs_cmp116FDerivHessian_half_projectedBilinearDiagonal_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116QuadraticCoreHessianAudit.lean:6:0: 'YangMills.RG.abs_cmp116FDerivHessian_half_projectedBilinearDiagonal_le_of_opNorm_le_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10228/10301] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit (24s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:3:0: 'YangMills.RG.sum_filter_fin_append' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:4:0: 'YangMills.RG.sum_cmp116Eq80Lemma1Combined_rootedResidual_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:5:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedRootBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:6:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedRootBound_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:7:0: 'YangMills.RG.cmp116Eq80Lemma1Combined_rooted_residual_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:8:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalRootBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:9:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalRootBound_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedRootedResidualAudit.lean:10:0: 'YangMills.RG.cmp116Eq80Lemma1Combined_rooted_residual_le_physical' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10229/10303] Built YangMills.RG.BalabanCMP116Eq80Lemma1SourceSmallFieldCarrier (16s)
# ✔ [10230/10304] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedKernelSupport (15s)
# ⚠ [10231/10304] Built YangMills.RG.BalabanCMP116InteractingPhysicalPrecisionSource (17s)
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:58:5: unused variable `X`
#
# Note: This linter can be disabled with `set_option linter.unusedVariables false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:83:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.sourceRange_bound`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:90:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.finiteRange`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:96:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.coercivity_pos`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:101:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.coercive`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:108:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.precision_comp_covariance`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSource.lean:118:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.exists_covariance_CT`:
#   [NeZero Q]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ✔ [10232/10305] Built YangMills.RG.BalabanCMP116ConditionedRootQBoundWall (16s)
# ℹ [10233/10305] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit (26s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:3:0: 'YangMills.RG.cmp116SmallFieldCutoff_ne_zero_of_subset' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:4:0: 'YangMills.RG.cmp116SignedCutoff_ne_zero_of_smallFieldCarrier_subset' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:5:0: 'YangMills.RG.cmp116SignedCutoff_eq_zero_of_mem_small_and_large' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:6:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedInteriorSignedCutoff_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:7:0: 'YangMills.RG.cmp102Eq80SourcePi4PhysicalY0_subset_combinedRegionInterior' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:8:0: 'YangMills.RG.physicalBondProjection_indexedSourceDomain_combinedCenteredRegion' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:9:0: 'YangMills.RG.cmp116DirectSignedCutoff_ne_zero_of_combinedInteriorCutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:10:0: 'YangMills.RG.norm_cmp116SourcePhysicalCoordinateCochain_lt_of_combinedInteriorCutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedCutoffCarrierAudit.lean:11:0: 'YangMills.RG.cmp109Lemma1SourceSmallField_combinedInteriorProjection_of_cutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10234/10306] Built YangMills.RG.BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit (30s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:3:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalVolumeCost' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:4:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalVolumeRate' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:5:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalVolumeRate_mul_alpha' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:6:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysical_volume_budget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:7:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysical_volume_target_iff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1CombinedVolumeBudgetAudit.lean:8:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedPhysicalVolumeCost_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10235/10307] Built YangMills.RG.BalabanCMP116LocalizedCovarianceCompression (25s)
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:105:37: This simp argument is unused:
#   Matrix.mul_assoc
#
# Hint: Omit it from the simp argument list.
#   simp [cmp116LocalizedCovarianceCompression, cmp116Eq223CoordinateProjection, M̵a̵t̵r̵i̵x̵.̵m̵u̵l̵_̵a̵s̵s̵o̵c̵,̵Matrix.diagonal_mul,
#       hi]
#
# Note: This linter can be disabled with `set_option linter.unusedSimpArgs false`
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:125:5: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:137:4: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:153:4: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:153:32: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:161:2: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:177:5: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:178:16: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:179:6: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# warning: YangMills/RG/BalabanCMP116LocalizedCovarianceCompression.lean:180:27: `Matrix.PosSemidef.sqrt` has been deprecated: Use `CFC.sqrt` instead
#
# Note: The updated constant has a different type:
#   {A : Type u_1} →
#     [inst : PartialOrder A] →
#       [inst_1 : NonUnitalRing A] →
#         [inst_2 : TopologicalSpace A] →
#           [inst_3 : StarRing A] →
#             [inst_4 : Module ℝ A] →
#               [inst_5 : SMulCommClass ℝ A A] →
#                 [inst_6 : IsScalarTower ℝ A A] →
#                   [StarOrderedRing A] →
#                     [NonUnitalContinuousFunctionalCalculus ℝ A IsSelfAdjoint] → [NonnegSpectrumClass ℝ A] → A → A
# instead of
#   {𝕜 : Type u_1} →
#     {n : Type u_2} →
#       [inst : RCLike 𝕜] → [Fintype n] → [DecidableEq n] → {A : Matrix n n 𝕜} → A.PosSemidef → Matrix n n 𝕜
#
# Note: The updated constant is in a different namespace. Dot notation may need to be changed (e.g., from `x.sqrt` to `CFC.sqrt x`).
# ℹ [10236/10308] Built YangMills.RG.BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit (21s)
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:3:0: 'YangMills.RG.mem_cmp116Eq214SmallFieldBondCarrier_of_sourceBlock_mem_Y0' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:4:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedSourceSmallFieldCarrier' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:5:0: 'YangMills.RG.cmp102Eq80SourcePi4PhysicalY0_subset_combinedSourceSmallFieldCarrier' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:6:0: 'YangMills.RG.cmp109Lemma1SourceBondSupport_subset_combinedSourceSmallFieldCarrier' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:7:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedSourceSmallFieldCarrier_disjoint_of_P_subset' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:8:0: 'YangMills.RG.cmp116SignedCutoff_piecewiseRealWitness_ne_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:9:0: 'YangMills.RG.cmp116Eq80Lemma1CombinedSourceSignedCutoff_piecewiseWitness_ne_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:10:0: 'YangMills.RG.cmp109Lemma1SourceSmallField_of_combinedSourceCutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116Eq80Lemma1SourceSmallFieldCarrierAudit.lean:11:0: 'YangMills.RG.cmp109Lemma1SourceSmallField_projectedCombinedRegion_of_sourceCutoff' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10237/10308] Built YangMills.RG.BalabanCMP102Eq80CouplingScaledSecondJet (82s)
# ℹ [10238/10309] Built YangMills.RG.BalabanCMP102Eq80SourcePi4RootedResidualAudit (20s)
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:3:0: 'YangMills.RG.sum_cmp102Eq80SourcePi4DomainAt_filter_blocks_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:4:0: 'YangMills.RG.cmp102Eq80SourcePi4DomainFamily_rooted_sum_pow_card_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:5:0: 'YangMills.RG.exp_neg_cmp102Eq80SourcePi4Metric_le_cardWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:6:0: 'YangMills.RG.cmp102Eq80SourcePi4DomainFamily_rooted_exp_metric_sum_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:7:0: 'YangMills.RG.cmp102Eq80SourcePi4DomainFamily_rooted_weighted_exp_metric_sum_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:8:0: 'YangMills.RG.cmp102Eq80SourcePi4DirectRootBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:9:0: 'YangMills.RG.cmp102Eq80SourcePi4DirectRootBound_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102Eq80SourcePi4RootedResidualAudit.lean:10:0: 'YangMills.RG.cmp102Eq80SourcePi4Indexed_rooted_residual_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10239/10310] Built YangMills.RG.BalabanCMP102Eq80PhysicalCombinedEq136 (45s)
# ℹ [10240/10310] Built YangMills.RG.BalabanCMP116RadialHessianThirdJetAudit (22s)
# info: YangMills/RG/BalabanCMP116RadialHessianThirdJetAudit.lean:3:0: 'YangMills.RG.abs_cmp116FDerivHessian_sub_le_of_thirdJet' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116RadialHessianThirdJetAudit.lean:4:0: 'YangMills.RG.abs_inner_cmp116RadialTaylorResidualOperator_le_of_thirdJet' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116RadialHessianThirdJetAudit.lean:5:0: 'YangMills.RG.abs_half_inner_cmp116RadialTaylorResidualOperator_le_of_thirdJet' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10241/10310] Built YangMills.RG.BalabanCMP116InteractingPhysicalPrecisionSourceAudit (38s)
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:9:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.sourceRange_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:10:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.finiteRange' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:11:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.coercivity_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:12:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.coercive' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:13:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.precision_comp_covariance' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP116InteractingPhysicalPrecisionSourceAudit.lean:14:0: 'YangMills.RG.CMP116InteractingPhysicalPrecisionSource.exists_covariance_CT' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10242/10311] Built YangMills.RG.BalabanCMP116InteractingConditionedCovariance (26s)
# warning: YangMills/RG/BalabanCMP116InteractingConditionedCovariance.lean:219:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.covariance_isSymmetric`:
#   [NeZero Q]
#   [NeZero (Nc ^ 2 - 1)]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] [NeZero (Nc ^ 2 - 1)] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingConditionedCovariance.lean:230:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.covariance_psd`:
#   [NeZero Q]
#   [NeZero (Nc ^ 2 - 1)]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero Q] [NeZero (Nc ^ 2 - 1)] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP116InteractingConditionedCovariance.lean:242:0: automatically included section variable(s) unused in theorem `YangMills.RG.CMP116InteractingPhysicalPrecisionSource.norm_covariance_le`:
#   [NeZero Q]
#   [NeZero (Nc ^ 2 - 1)]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
# ...
#  Classical.choice,
#  Quot.sound]
# ✔ [10917/10943] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecay (42s)
# ✔ [10918/10943] Built YangMills.RG.BalabanCMP99SourceEq395RegionalMiddleCommutatorDecay (49s)
# ℹ [10919/10943] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixLaplacianOwnerDecayAudit (13s)
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLaplacianOwnerDecayAudit.lean:5:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefixLaplacian_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10920/10943] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixEq342Certificate (10s)
# ℹ [10921/10943] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit (19s)
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:7:0: 'YangMills.RG.cmp99ActiveRegionSourceCovariantD0CLM_adjoint_apply' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:8:0: 'YangMills.RG.finitePiLpSupNorm_cmp99ActiveRegionSourceCovariantD0CLM_adjoint_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:9:0: 'YangMills.RG.cmp99ActiveRegionSourceCovariantD0CLM_adjoint_apply_eq_zero_of_owner_far' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:10:0: 'YangMills.RG.finitePiLpTypedBlockLocalizedSupBound_comp_of_ownerKernel' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixRightAdjointOwnerDecayAudit.lean:11:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefixRightAdjoint_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10922/10943] Built YangMills.RG.BalabanCMP96SourceSeparatedRegionalPrefixEq342CertificateAudit (12s)
# info: YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixEq342CertificateAudit.lean:12:0: 'YangMills.RG.cmp96SourceSeparatedRegionalPrefix_eq342SourceLocalizedGreenCertificate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10923/10943] Built YangMills.RG.BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit (28s)
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceMiddleAmbient_eq_extend_onSource' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceMiddleAmbient_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalMiddle_smoothCommutator_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalMiddleCommutatorDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedLeftDefect_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10924/10943] Built YangMills.RG.BalabanCMP99SourceEq395RegionalCovarianceDecay (29s)
# ✔ [10925/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedRAtomDecay (11s)
# ℹ [10926/10943] Built YangMills.RG.BalabanCMP99SourceEq395RegionalCovarianceDecayAudit (16s)
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalCovarianceDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceCoordinates_eq_onSource' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395RegionalCovarianceDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.generatedPhysicalCoarseCovarianceAmbient_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10927/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedRAtomDecayAudit (14s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomInputRate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomDecayRate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtomDecayAmplitude' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedRAtomDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGroupedRAtom_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10928/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedCorrectionDecay (26s)
# ℹ [10929/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedCorrectionDecayAudit (23s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_grouped_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.norm_cmp99Eq395PhysicalCorrection_le_groupedSchurAmplitude' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedCorrectionDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalGlobalMiddle_comp_correctedCovariance_eq_id_of_groupedSchurSmall' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10930/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedNeumannDecay (29s)
# ✔ [10931/10943] Built YangMills.RG.BalabanCMP99SourceEq395PatchedCovarianceDecay (12s)
# ℹ [10932/10943] Built YangMills.RG.BalabanCMP99SourceEq395GroupedNeumannDecayAudit (28s)
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_grouped_weightedRow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.norm_cmp99Eq395PhysicalCorrection_le_groupedNeumannRatio' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_pow_grouped_weightedRow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395GroupedNeumannDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrection_tsum_pow_grouped_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10933/10943] Built YangMills.RG.BalabanCMP99SourceEq395CanonicalCovariance (16s)
# ℹ [10934/10943] Built YangMills.RG.BalabanCMP99SourceEq395PatchedCovarianceDecayAudit (19s)
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:3:0: 'YangMills.RG.cmp99SourceSquarePartition_sum_norm_mul_norm_le_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:4:0: 'YangMills.RG.finitePiLpExponentialKernelBound_squarePartition_sum' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalPatchedCovariance_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395PatchedCovarianceDecayAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrectedCovariance_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10935/10943] Built YangMills.RG.BalabanCMP99SourceEq395CanonicalCovarianceAudit (29s)
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:3:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCanonicalCovariance' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:4:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395FullCoarseRegion_extendZero_comp_restrict_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:5:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395GeneratedPhysicalCovarianceOnSource_comp_middle' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:6:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCanonicalCovariance_comp_globalMiddle_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq395CanonicalCovarianceAudit.lean:7:0: 'YangMills.RG.CMP99SourceDependentOmegaGeometry.cmp99Eq395PhysicalCorrectedCovariance_eq_canonical' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10936/10943] Built YangMills.RG.BalabanCMP99SourceEq3163Hprime (74s)
# ℹ [10937/10943] Built YangMills.RG.BalabanCMP99SourceEq3163HprimeAudit (17s)
# info: YangMills/RG/BalabanCMP99SourceEq3163HprimeAudit.lean:3:0: 'YangMills.RG.cmp99SourceEq3163PhysicalHprime' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq3163HprimeAudit.lean:4:0: 'YangMills.RG.cmp99SourceEq3163_Qprime_comp_physicalHprime_eq_id' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10938/10943] Built YangMills.RG.BalabanCMP99SourceEq325GaugeProjection (30s)
# ✔ [10939/10943] Built YangMills.RG.BalabanCMP99SourceEq326ProjectedGaugeMass (28s)
# ℹ [10940/10943] Built YangMills.RG.BalabanCMP99SourceEq325GaugeProjectionAudit (46s)
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:3:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:4:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:5:0: 'YangMills.RG.cmp99Eq325Complement_comp_self_of_middle_comp_inverse' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:6:0: 'YangMills.RG.cmp99Eq325Projection_comp_self_of_complement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:7:0: 'YangMills.RG.cmp99Eq325_QG_comp_projection_eq_zero_of_middle_comp_inverse' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:8:0: 'YangMills.RG.cmp99Eq325Complement_isSymmetric_of_weightedAdjoint' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:9:0: 'YangMills.RG.cmp99Eq325Projection_isSymmetric_of_complement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:10:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement_comp_self' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:11:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection_comp_self' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:12:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeComplement_isSymmetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:13:0: 'YangMills.RG.cmp99SourceEq325PhysicalGaugeProjection_isSymmetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq325GaugeProjectionAudit.lean:14:0: 'YangMills.RG.cmp99SourceEq325_Qprime_comp_green_comp_projection_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10941/10943] Built YangMills.RG.BalabanCMP99SourceEq326ProjectedGaugeMassAudit (32s)
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:3:0: 'YangMills.RG.cmp99ProjectedGaugeMassCLM' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:4:0: 'YangMills.RG.inner_cmp99ProjectedGaugeMassCLM_eq_norm_sq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:5:0: 'YangMills.RG.inner_cmp99ProjectedGaugeMassCLM_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:6:0: 'YangMills.RG.cmp99ProjectedGaugeMassCLM_isSymmetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:7:0: 'YangMills.RG.cmp99SourceEq326ProjectedGaugeMass' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:8:0: 'YangMills.RG.inner_cmp99SourceEq326ProjectedGaugeMass_eq_norm_sq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:9:0: 'YangMills.RG.inner_cmp99SourceEq326ProjectedGaugeMass_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceEq326ProjectedGaugeMassAudit.lean:10:0: 'YangMills.RG.cmp99SourceEq326ProjectedGaugeMass_isSymmetric' depends on axioms: [propext, Classical.choice, Quot.sound]
# Some required targets logged failures:
# - YangMills.RG.BalabanCMP99Eq335PhysicalRetainedNearIdentity
# error: build failed
#
# STAGE=c6d_localized_retained_tower_root EXIT=1 SECONDS=10502.589
# ERROR=RuntimeError('FIRST_ERROR=c6d_localized_retained_tower_root')
# EVIDENCE_SHA256=a240040d7e267493da238f772297e0302e6b801843df4d0b74df5fd284bc183c
# EVIDENCE_ARCHIVE=/content/hrpoly-c6d-localized-retained-tower-evidence.tar.gz
# EVIDENCE_ARCHIVE_SHA256=cb28384130f12913f157829b98f254a0d140a016d3bdfbf0e7325cbb6f6d499a
# FINAL_STATUS=FAIL
# RUNTIME_UNASSIGN_DEFERRED=1
# RUNTIME_UNASSIGN_REQUESTED=1
# LAUNCHER_EXIT=1
# RUNTIME_RETAINED_FOR_DEBUG=1
# Traceback (most recent call last):
#   File "/content/colab_qprime_row_validation.py", line 261, in main
#     output = run(stage, command, cwd=ROOT)
#   File "/content/colab_qprime_row_validation.py", line 111, in run
#     raise RuntimeError("FIRST_ERROR=" + stage)
# RuntimeError: FIRST_ERROR=c6d_localized_retained_tower_root
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1203/2018771987.py in <cell line: 0>()
#      26         print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
#      27 if launcher_exit != 0:
# ---> 28     raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
#
# RuntimeError: RUNNER_EXIT=1

# %%
from google.colab import files
files.download('/content/hrpoly-c6d-localized-retained-tower-evidence.tar.gz')
