# %%
import hashlib, urllib.request
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/71fd94dd1afef8fe5657c3c6dcb3a5c709ad64f6/scripts/colab_cmp89_eq246_integrand_one_coordinate_shift_validation.py"
RUNNER_SHA256 = "241bf1df6adbc36ce9056a302749987427dcba4f8da003da5e210ce7a4e84990"
with urllib.request.urlopen(RUNNER_URL, timeout=60) as response:
    runner_source = response.read()
runner_hash = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + runner_hash, flush=True)
if runner_hash != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
launcher_exit = 0
runner_namespace = {"__name__": "__main__"}
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), runner_namespace)
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
runner_module = runner_namespace.get("runner")
archive = getattr(runner_module, "ARCHIVE", None)
if archive is not None and archive.is_file():
    archive_hash = hashlib.sha256(archive.read_bytes()).hexdigest()
    print("LAUNCHER_EVIDENCE_ARCHIVE=" + str(archive), flush=True)
    print("LAUNCHER_EVIDENCE_ARCHIVE_SHA256=" + archive_hash, flush=True)
print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
print("LAUNCHER_RUNTIME_RETAINED=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")

# %%
from pathlib import Path
import json, hashlib
E = Path("/content/hrpoly-cmp89-eq246-integrand-one-coordinate-shift-cold-v1-evidence/evidence.json")
A = Path("/content/hrpoly-cmp89-eq246-integrand-one-coordinate-shift-cold-v1-evidence.tar.gz")
print("EVIDENCE_EXISTS=" + str(E.is_file()))
print("ARCHIVE_EXISTS=" + str(A.is_file()))
if E.is_file():
    p = json.loads(E.read_text())
    print("FINAL_STATUS=" + str(p.get("status")))
    print("RUNNER_REV=" + str(p.get("runner_rev")))
    print("SOURCE_SHA=" + str(p.get("source_sha")))
    print("EVIDENCE_JSON_SHA256=" + hashlib.sha256(E.read_bytes()).hexdigest())
    for r in p.get("records", []):
        print("RECORD=" + str(r.get("stage")) + " EXIT=" + str(r.get("exit_code")) + " SECONDS=" + str(r.get("seconds")))
if A.is_file():
    print("ARCHIVE_SHA256=" + hashlib.sha256(A.read_bytes()).hexdigest())
# Out:
# EVIDENCE_EXISTS=True
# ARCHIVE_EXISTS=True
# FINAL_STATUS=PASS
# RUNNER_REV=cmp89-eq246-integrand-one-coordinate-shift-cold-v1
# SOURCE_SHA=881a6de1c6c945161c65f9d9966319b17e386e4c
# EVIDENCE_JSON_SHA256=1c313b1b51ec84df22fcff706d2299dfe377309f7b491e41d82cdd19b1b771de
# RECORD=download_toolchain EXIT=None SECONDS=1.8853650419999894
# RECORD=apt_update EXIT=None SECONDS=5.607969878000063
# RECORD=install_zstd EXIT=None SECONDS=7.635525607999966
# RECORD=extract_toolchain EXIT=None SECONDS=9.628738580000004
# RECORD=lean_version EXIT=None SECONDS=0.05780632699998023
# RECORD=lake_version EXIT=None SECONDS=0.06147826000005807
# RECORD=clone EXIT=None SECONDS=15.935911360999967
# RECORD=checkout EXIT=None SECONDS=1.571906471000034
# RECORD=head EXIT=None SECONDS=0.0029831680000143024
# RECORD=overlay_text_guard EXIT=None SECONDS=0.05832762800002911
# RECORD=import_prefix_guard EXIT=None SECONDS=0.04733334599995942
# RECORD=lake_update EXIT=None SECONDS=107.4704122359999
# ...
