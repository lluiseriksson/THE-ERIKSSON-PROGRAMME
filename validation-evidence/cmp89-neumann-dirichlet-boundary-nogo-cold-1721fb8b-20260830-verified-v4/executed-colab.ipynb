# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/be4c87beb222487e3928c6063781fef0c14c87b7/scripts/colab_cmp89_neumann_centered_rectangular_representative_validation.py"
RUNNER_SHA256 = "b6166a9e1ea15fa04e4b62f077ee57698fc3265c2f74092f5cd4295191874f17"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
release_runtime = runtime.unassign
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    if launcher_exit == 0:
        print("RUNTIME_RETAINED_FOR_EVIDENCE_DOWNLOAD=1", flush=True)
    else:
        print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")

# %%
from google.colab import files
files.download('/content/hrpoly-cmp89-uniform-owner-certificate-cold-40f025a2-evidence.tar.gz')

# %%
from google.colab import runtime
runtime.unassign()

# %%
import subprocess
print(subprocess.run(['bash','-lc',"ps -eo pid,ppid,stat,etime,pcpu,pmem,rss,cmd --sort=-pcpu | head -20"],capture_output=True,text=True).stdout)
# Out:
#     PID    PPID STAT     ELAPSED %CPU %MEM   RSS CMD
#   36260    9020 Sl+        00:05 91.6 12.1 6488800 /content/lean-4.29.0-rc6-linux/lean-4.29.0-rc6-linux/bin/lean /content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c/YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLeftDerivativeOwnerDecay.lean -o /content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c/.lake/build/lib/lean/YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLeftDerivativeOwnerDecay.olean -i /content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c/.lake/build/lib/lean/YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLeftDerivativeOwnerDecay.ilean -c /content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c/.lake/build/ir/YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLeftDerivativeOwnerDecay.c --setup /content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c/.lake/build/ir/YangMills/RG/BalabanCMP96SourceSeparatedRegionalPrefixLeftDerivativeOwnerDecay.setup.json --json
#    9020    7183 Sl+     01:26:31  5.0  2.1 1129264 lake build YangMills.RG.BalabanCMP99Eq342UniformCertificateFromValueBound
#      82       7 Z       01:58:11  0.2  0.0     0 [python3] <defunct>
#    7183    7088 S+      01:29:01  0.2  0.0 19748 python3 /content/run_eq342_uniform_adapter.py
#     115       7 Sl      01:58:09  0.1  0.3 162056 /usr/bin/python3 /usr/local/bin/jupyter-server --debug --transport="ipc" --ip=172.28.0.12 --ServerApp.token= --port=9000 --FileContentsManager.root_dir=/ --FileContentsManager.allow_hidden=True --ServerApp.log_format="|%(levelname)s|%(message)s" --ServerApp.iopub_data_rate_limit=1e10 --MappingKernelManager.root_dir=/content
#    7077    7062 Sl      01:29:20  0.1  0.3 186076 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:b2d5fbd22b6ac134c0e0372ecddb5527e74b55ad52
#       1       0 Ss      01:58:14  0.0  0.0   552 /sbin/docker-init -- /datalab/run.sh
#       7       1 Sl      01:58:14  0.0  0.1 65620 /tools/node/bin/node /datalab/web/app.js
#       9       7 S       01:58:14  0.0  0.0  3548 /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
#      11       1 S       01:58:14  0.0  0.0  1892 /bin/bash -e /datalab/run.sh
#      12      11 Sl      01:58:14  0.0  0.0 36012 /usr/colab/bin/kernel_manager_proxy --listen_port=6000 --target_port=9000 --logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-hm-kkb-use4b2-247k4g1zuiqfh --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true --use_oneplatform_for_bg_save=true
#      41       0 Ss      01:58:13  0.0  0.0  2076 tail -n +0 -F /root/.config/Google/DriveFS/Logs/dpb.txt
#      47       0 Ss      01:58:13  0.0  0.0  2140 tail -n +0 -F /root/.config/Google/DriveFS/Logs/drive_fs.txt
#      83       7 S       01:58:11  0.0  0.1 78500 python3 /usr/local/bin/colab-fileshim.py
#      96       1 Ss      01:58:10  0.0  0.0  4220 sshd: /usr/sbin/sshd [listener] 0 of 1-1 startups
#    7035     115 Ssl     01:29:23  0.0  0.1 103112 /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-d4227b57-1e16-4187-997e-d33fdcf3c5b2.json
#    7062       7 Sl      01:29:21  0.0  0.0 18560 /usr/colab/bin/language_service -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:b2d5fbd22b6ac134c0e0372ecddb5527e74b55ad52
#    7084       7 Ss+     01:29:20  0.0  0.0  4104 tmux new-session -A -D -s 0
#    7087       1 Ss      01:29:20  0.0  0.0  4116 tmux new-session -A -D -s 0

# %%
from google.colab import files
files.download('/content/hrpoly-cmp99-eq342-uniform-adapter-cold-d8db241c-evidence.tar.gz')

# %%
from google.colab import runtime
runtime.unassign()

# %%
import hashlib, urllib.request
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/8e3e8a6fef9a812546e6550fa432507697fe78a6/scripts/colab_cmp89_neumann_dirichlet_boundary_nogo_validation.py"
RUNNER_SHA256 = "bc560edef280f23c754a5140570cf0c7bf94664b28ee521711a471bfabc9998a"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:14:0: 'YangMills.RG.cmp89Eq251EuclideanNorm_le_central_radius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:15:0: 'YangMills.RG.rpow_le_one_add_self_of_mem_Icc' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:16:0: 'YangMills.RG.cmp89Eq249_unit_div_scaled_central_alias_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251CentralRealIntegrandBoundAudit.lean:17:0: 'YangMills.RG.cmp89Eq251CentralRealIntegrand_le_constant' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10463/10671] Built YangMills.RG.BalabanCMP89Eq251FiniteRealIntegrandSumAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:10:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandSum' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:11:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandBound' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251FiniteRealIntegrandSumAudit.lean:12:0: 'YangMills.RG.cmp89Eq251FiniteRealIntegrandSum_le_bound' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10464/10694] Built YangMills.RG.BalabanCMP99SourceGeneratedFlatPhysicalPrecisionKernel (40s)
# ✔ [10465/10696] Built YangMills.RG.BalabanCMP89Eq249NoncentralRealGap (14s)
# ✔ [10466/10700] Built YangMills.RG.BalabanCMP99SourceCoarseFibreFourierNeg (11s)
# ✔ [10467/10700] Built YangMills.RG.BalabanCMP89CenteredUnitCubeTorusQuotient (7.0s)
# ✔ [10468/10701] Built YangMills.RG.BalabanCMP99FlatComplexFibrePointSourceFourierReconstruction (11s)
# ✔ [10469/10702] Built YangMills.RG.BalabanCMP99FlatFiniteGridAliasing (11s)
# ✔ [10470/10703] Built YangMills.RG.BalabanCMP89CenteredPeriodicL1ResidueSum (9.3s)
# ℹ [10471/10704] Built YangMills.RG.BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit (9.8s)
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:5:0: 'YangMills.RG.cmp89Eq246EntireAliasPrecisionMatrix_mulVec' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:6:0: 'YangMills.RG.differentiable_cmp89Eq246EntireAliasPrecisionMatrix_entry' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:7:0: 'YangMills.RG.cmp89Eq246EntireAliasAverageRow_ofReal_eq_conj' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq246EntireAliasPrecisionMatrixAudit.lean:8:0: 'YangMills.RG.cmp89Eq246EntireAliasFineSymbol_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10472/10705] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit (8.4s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:5:0: 'YangMills.RG.cmp89Eq249ZeroAlias_mem' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:6:0: 'YangMills.RG.cmp89Eq247ComplexReducedAliasDenominator_eq_central_add_noncentral' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedAliasDenominatorAudit.lean:7:0: 'YangMills.RG.cmp89Eq249CentralFine_mul_reduced_eq_stabilized' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10473/10706] Built YangMills.RG.BalabanCMP99SourceCoarseFibreFourierNegQuotientCarry (11s)
# info: YangMills/RG/BalabanCMP99SourceCoarseFibreFourierNegQuotientCarry.lean:77:46: Try this:
#   [apply] ring_nf
#
#   The `ring` tactic failed to close the goal. Use `ring_nf` to obtain a normal form.
#
#   Note that `ring` works primarily in *commutative* rings. If you have a noncommutative ring, abelian group or module, consider using `noncomm_ring`, `abel` or `module` instead.
# ✔ [10474/10707] Built YangMills.RG.BalabanCMP89Eq249NoncentralComplexGap (16s)
# ℹ [10475/10708] Built YangMills.RG.BalabanCMP89Eq245EntireAverageStripGrowthAudit (7.9s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_le_exp' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_le_exp' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_le_exp_pow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageStripGrowthAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_mul_neg_le_exp_pow' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10476/10708] Built YangMills.RG.BalabanCMP89Eq245EntireAverageVerticalVariationAudit (7.9s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:3:0: 'YangMills.RG.cmp89Eq245EntireAverageBase_pow_eq_exp_modeExponent' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageModeExponent_sub_realSlice_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:5:0: 'YangMills.RG.norm_complex_exp_sub_exp_le_of_norm_sub_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageVerticalVariationAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10477/10710] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit (7.2s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:3:0: 'YangMills.RG.norm_fin_prod_sub_prod_le_card_mul' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:5:0: 'YangMills.RG.cmp89Eq245ComplexMomentumRealSlice_neg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAmplitudeVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_pair_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10478/10713] Built YangMills.RG.BalabanCMP89Eq245EntireLaplacianVariationAudit (8.1s)
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifferenceExponent_sub_realSlice_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_ofReal_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:6:0: 'YangMills.RG.norm_mul_sub_mul_le_eps_mul_two_mul_add' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_pair_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireLaplacianVariationAudit.lean:8:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledLaplacianSymbol_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ⚠ [10479/10715] Built YangMills.RG.BalabanCMP85Eq230CoarseCovariance (42s)
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:75:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp85SourceStepWeightedAdjoint_pairing`:
#   [NeZero M]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero M] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:98:22: This simp argument is unused:
#   conj_trivial
#
# Hint: Omit it from the simp argument list.
#   simp only [mul_pow,̵ ̵c̵o̵n̵j̵_̵t̵r̵i̵v̵i̵a̵l̵]
#
# Note: This linter can be disabled with `set_option linter.unusedSimpArgs false`
# warning: YangMills/RG/BalabanCMP85Eq230CoarseCovariance.lean:104:0: automatically included section variable(s) unused in theorem `YangMills.RG.cmp85SourceStepWeightedTerm_eq_counting`:
#   [NeZero M]
# consider restructuring your `variable` declarations so that the variables are not in scope or explicitly omit them:
#   omit [NeZero M] in theorem ...
#
# Note: This linter can be disabled with `set_option linter.unusedSectionVars false`
# ℹ [10480/10722] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedRealLowerAudit (20s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:5:0: 'YangMills.RG.cmp89Eq249ComplexNoncentralAliasSum_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:6:0: 'YangMills.RG.cmp89Eq249CentralEntireAveragePair_ofReal_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:7:0: 'YangMills.RG.cmp89Eq249CentralStabilizedAliasDenominator_ofReal_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:8:0: 'YangMills.RG.cmp89Eq249RealNoncentralAliasSum_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:9:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_real' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:10:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_re' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:11:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_mono' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedRealLowerAudit.lean:12:0: 'YangMills.RG.cmp85Eq215Floor_le_cmp89Eq249CentralStabilizedAliasDenominator_re' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10481/10723] Built YangMills.RG.BalabanCMP89Eq249NoncentralRealGapAudit (19s)
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:5:0: 'YangMills.RG.one_div_nine_le_cmp89Eq245ScaledLaplacianSymbol_noncentral_alias' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:6:0: 'YangMills.RG.cmp89Eq245ScaledLaplacianSymbol_noncentral_alias_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:7:0: 'YangMills.RG.cmp89Eq250AliasDenominatorSummand_noncentral_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:8:0: 'YangMills.RG.cmp89Eq249RealNoncentralAliasSum_nonneg_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:9:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_real_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:10:0: 'YangMills.RG.cmp89Eq249CentralStabilizedLowerConstant_le_re_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralRealGapAudit.lean:11:0: 'YangMills.RG.cmp85Eq215Floor_le_cmp89Eq249CentralStabilizedAliasDenominator_re_massUniform' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10482/10725] Built YangMills.RG.BalabanCMP89Eq249UniformNoncentralComplexRadius (9.7s)
# ℹ [10483/10725] Built YangMills.RG.BalabanCMP89Eq249NoncentralComplexGapAudit (11s)
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:3:0: 'YangMills.RG.sum_abs_le_two_mul_cmp89Eq251EuclideanNorm_fin_four' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:4:0: 'YangMills.RG.cmp89Eq245EntireScaledLaplacianVerticalBudget_le_noncentralGapBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:5:0: 'YangMills.RG.half_real_gap_le_norm_of_norm_sub_le_half' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:6:0: 'YangMills.RG.half_momentum_gap_le_norm_cmp89Eq245EntireScaledLaplacianSymbol' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249NoncentralComplexGapAudit.lean:7:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledLaplacianSymbol_noncentral_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10484/10725] Built YangMills.RG.PeriodicHolomorphicVerticalShiftAudit (5.8s)
# info: YangMills/RG/PeriodicHolomorphicVerticalShiftAudit.lean:5:0: 'YangMills.RG.intervalIntegral_eq_verticalShift_of_periodic_of_differentiableOn' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10485/10728] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAliasStripBoundAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageBase_pow_sub_one_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:5:0: 'YangMills.RG.cmp89Eq245EntireAverageFactor_eq_geometricQuotient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:6:0: 'YangMills.RG.one_div_three_pi_mul_abs_le_norm_cmp89Eq245EntireAverageBase_sub_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:7:0: 'YangMills.RG.one_div_six_pi_mul_abs_le_norm_cmp89Eq245EntireAverageBase_sub_one' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:8:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageFactor_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasStripBoundAudit.lean:9:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10486/10730] Built YangMills.RG.BalabanCMP85ScalarRecurrence (7.8s)
# ℹ [10487/10734] Built YangMills.RG.HolomorphicVerticalShiftBoundaryAudit (6.1s)
# info: YangMills/RG/HolomorphicVerticalShiftBoundaryAudit.lean:16:0: 'YangMills.RG.intervalIntegral_eq_verticalShift_of_boundary_eq_of_differentiableOn' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10488/10745] Built YangMills.RG.BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit (9.6s)
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_scaled_alias_le_of_zone' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:4:0: 'YangMills.RG.cmp89Eq251MultidimensionalAliasWeight_neg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq245EntireAverageAmplitude_neg_realSlice_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq245EntireAverageAliasWeightedVariationAudit.lean:6:0: 'YangMills.RG.norm_cmp89Eq245EntireAveragePair_alias_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10489/10763] Built YangMills.RG.BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit (8.8s)
# info: YangMills/RG/BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit.lean:3:0: 'YangMills.RG.cmp89Eq249NoncentralComplexGapBudget_le_of_uniformRadiusCondition' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249UniformNoncentralComplexRadiusAudit.lean:4:0: 'YangMills.RG.half_momentum_gap_le_norm_cmp89Eq245EntireScaledLaplacianSymbol_of_uniformRadius' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10490/10766] Built YangMills.RG.IntervalIntegralSliceTransportAudit (6.1s)
# info: YangMills/RG/IntervalIntegralSliceTransportAudit.lean:3:0: 'YangMills.RG.intervalIntegral_integral_eq_of_slice_intervalIntegral_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10491/10767] Built YangMills.RG.BalabanCMP89Eq251EntireScaledDifferenceStripUpperAudit (5.3s)
# info: YangMills/RG/BalabanCMP89Eq251EntireScaledDifferenceStripUpperAudit.lean:12:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_le_abs_re_add_vertical' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10492/10769] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientBound (9.4s)
# ℹ [10493/10769] Built YangMills.RG.IntervalIntegralPiCoordinateTransportAudit (8.4s)
# info: YangMills/RG/IntervalIntegralPiCoordinateTransportAudit.lean:3:0: 'YangMills.RG.intervalIntegral_integral_eq_of_slice_intervalIntegral_ae_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/IntervalIntegralPiCoordinateTransportAudit.lean:4:0: 'YangMills.RG.integral_pi_restrict_uIoc_eq_of_coordinate_intervalIntegral_ae_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10494/10769] Built YangMills.RG.BalabanCMP89CenteredBrillouinAffineSlice (4.3s)
# ✔ [10495/10771] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBound (11s)
# ✔ [10496/10771] Built YangMills.RG.BalabanCMP85BlockGaussianAlgebra (10s)
# ℹ [10497/10771] Built YangMills.RG.BalabanCMP99FlatFiniteGridAliasingAudit (12s)
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:3:0: 'YangMills.RG.cmp99FlatIntegerResidue' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:4:0: 'YangMills.RG.CMP99FlatIntegerResidueClass' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:5:0: 'YangMills.RG.norm_cmp99FlatZModFourierCharacter' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:6:0: 'YangMills.RG.cmp99Flat_normalizedCharacterAverage_integerResidue' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:7:0: 'YangMills.RG.summable_cmp99FlatZModFourierCharacter_mul_integerCoefficient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:8:0: 'YangMills.RG.cmp99FlatFiniteGridFourierSeriesSample' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatFiniteGridAliasingAudit.lean:9:0: 'YangMills.RG.cmp99Flat_normalizedFiniteGridFourierSeriesSample_eq_residueClass' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10498/10773] Built YangMills.RG.BalabanCMP89CenteredBrillouinAffineSliceAudit (7.7s)
# info: YangMills/RG/BalabanCMP89CenteredBrillouinAffineSliceAudit.lean:6:0: 'YangMills.RG.cmp89CenteredBrillouin_affineSlice' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredBrillouinAffineSliceAudit.lean:7:0: 'YangMills.RG.cmp89CenteredBrillouin_affineSlice_complex' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10499/10774] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumBound (8.2s)
# ✔ [10500/10776] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariation (10s)
# ℹ [10501/10776] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq245EntireAveragePair_scaled_alias_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_le_radialWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientBoundAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10502/10783] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit (12s)
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:11:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointRadialConstant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:12:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientConstant' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:13:0: 'YangMills.RG.norm_cmp89Eq245EntireScaledDifference_alias_le_two_euclidean' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:14:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotient_le_radialWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientBoundAudit.lean:15:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotient_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10503/10785] Built YangMills.RG.BalabanCMP89CenteredUnitCubeTorusQuotientAudit (16s)
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:6:0: 'YangMills.RG.CMP89CenteredUnitInterval' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:7:0: 'YangMills.RG.CMP89CenteredUnitCube' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:8:0: 'YangMills.RG.cmp89CenteredUnitLeft' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:9:0: 'YangMills.RG.cmp89CenteredUnitRight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:10:0: 'YangMills.RG.cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:11:0: 'YangMills.RG.cmp89CenteredUnitInterval_eq_or_oppositeEndpoints' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:12:0: 'YangMills.RG.cmp89CenteredUnitCubeReplace' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:13:0: 'YangMills.RG.cmp89CenteredUnitCube_update_eq_of_faceSeam' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:14:0: 'YangMills.RG.cmp89CenteredUnitCube_factorsThrough_of_faceSeam' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:15:0: 'YangMills.RG.continuous_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:16:0: 'YangMills.RG.surjective_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:17:0: 'YangMills.RG.isQuotientMap_cmp89CenteredUnitCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:18:0: 'YangMills.RG.cmp89CenteredUnitCubeCovering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:19:0: 'YangMills.RG.isQuotientMap_cmp89CenteredUnitCubeCovering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:20:0: 'YangMills.RG.cmp89CenteredUnitCubeLift' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:21:0: 'YangMills.RG.cmp89CenteredUnitCubeLift_comp_covering' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:22:0: 'YangMills.RG.cmp89CenteredUnitRealCubeMeasure' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:23:0: 'YangMills.RG.cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:24:0: 'YangMills.RG.measurePreserving_cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredUnitCubeTorusQuotientAudit.lean:25:0: 'YangMills.RG.integral_cmp89CenteredUnitRealCubeToTorus' depends on axioms: [propext, Classical.choice, Quot.sound]
# ✔ [10504/10787] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSum (7.6s)
# ℹ [10505/10797] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumBoundAudit (8.0s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumBoundAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq249ComplexNoncentralAliasSum_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10506/10799] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit (9.4s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:3:0: 'YangMills.RG.norm_div_sub_div_le_of_lower_bounds' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:4:0: 'YangMills.RG.cmp89Eq248EntireAliasMomentum_realSlice_eq' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasQuotientVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_sub_realSlice_le_radial' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10507/10799] Built YangMills.RG.BalabanCMP89NeumannReflectionBranchSum (5.6s)
# ✔ [10508/10801] Built YangMills.RG.BalabanCMP89CenteredRectangularL1ResidueSum (4.0s)
# ✔ [10509/10801] Built YangMills.RG.BalabanCMP85TypedSchurBrackets (13s)
# ✔ [10510/10805] Built YangMills.RG.BalabanCMP89NeumannReflectionOrbitAlgebra (4.6s)
# ℹ [10511/10805] Built YangMills.RG.BalabanCMP89NeumannReflectionBranchSumAudit (5.5s)
# info: YangMills/RG/BalabanCMP89NeumannReflectionBranchSumAudit.lean:8:0: 'YangMills.RG.cmp89NeumannReflectionBranchCenteredSum_eq_two_pow_mul' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionBranchSumAudit.lean:9:0: 'YangMills.RG.cmp89NeumannReflectionBranchCenteredSum_le_geometric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10512/10821] Built YangMills.RG.BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit (10s)
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:11:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientSum' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:12:0: 'YangMills.RG.cmp89Eq251ComplexNoncentralEndpointQuotientSumBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq251ComplexNoncentralEndpointQuotientSumAudit.lean:13:0: 'YangMills.RG.norm_cmp89Eq251ComplexNoncentralEndpointQuotientSum_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10514/10822] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumVariation (16s)
# ℹ [10516/10823] Built YangMills.RG.BalabanCMP89CenteredRectangularL1ResidueSumAudit (6.5s)
# info: YangMills/RG/BalabanCMP89CenteredRectangularL1ResidueSumAudit.lean:7:0: 'YangMills.RG.cmp89CenteredRectangularL1ResidueWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredRectangularL1ResidueSumAudit.lean:8:0: 'YangMills.RG.cmp89CenteredRectangularL1ResidueWeight_eq_signedLatticeWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredRectangularL1ResidueSumAudit.lean:9:0: 'YangMills.RG.summable_cmp89CenteredRectangularL1ResidueWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredRectangularL1ResidueSumAudit.lean:10:0: 'YangMills.RG.tsum_cmp89CenteredRectangularL1ResidueWeight_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10517/10824] Built YangMills.RG.BalabanCMP89CenteredPeriodicL1ResidueSumAudit (14s)
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:7:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:8:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:9:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_neg_neg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:10:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_nat_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:11:0: 'YangMills.RG.cmp89CenteredPeriodicOneDimensionalExpWeight_neg_add_one_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:12:0: 'YangMills.RG.summable_cmp89CenteredPeriodicOneDimensionalExpWeight_of_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:13:0: 'YangMills.RG.summable_cmp89CenteredPeriodicOneDimensionalExpWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:14:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicOneDimensionalExpWeight_le_of_nonneg' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:15:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicOneDimensionalExpWeight_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:16:0: 'YangMills.RG.cmp89CenteredPeriodicL1ResidueWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:17:0: 'YangMills.RG.cmp89CenteredPeriodicL1ResidueWeight_eq_signedLatticeWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:18:0: 'YangMills.RG.summable_pi_int_prod_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:19:0: 'YangMills.RG.tsum_pi_int_prod_nonneg' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:20:0: 'YangMills.RG.summable_cmp89CenteredPeriodicL1ResidueWeight' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:21:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:22:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_physical_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89CenteredPeriodicL1ResidueSumAudit.lean:23:0: 'YangMills.RG.tsum_cmp89CenteredPeriodicL1ResidueWeight_physical_uniform_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10518/10826] Built YangMills.RG.BalabanCMP89NeumannReflectionScaleDictionary (4.6s)
# ℹ [10519/10826] Built YangMills.RG.BalabanCMP89NeumannReflectionOrbitAlgebraAudit (4.9s)
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:8:0: 'YangMills.RG.cmp89NeumannReflectionOrbit_false' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:9:0: 'YangMills.RG.cmp89NeumannReflectionOrbit_true' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:10:0: 'YangMills.RG.cmp89NeumannLeftReflection_orbit_false' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:11:0: 'YangMills.RG.cmp89NeumannLeftReflection_orbit_true' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:12:0: 'YangMills.RG.cmp89NeumannRightReflection_orbit_false' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:13:0: 'YangMills.RG.cmp89NeumannRightReflection_orbit_true' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:14:0: 'YangMills.RG.cmp89NeumannRight_left_orbit_false' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:15:0: 'YangMills.RG.cmp89NeumannLeft_right_orbit_false' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionOrbitAlgebraAudit.lean:16:0: 'YangMills.RG.cmp89NeumannReflectionImage_apply' does not depend on any axioms
# ✔ [10520/10826] Built YangMills.RG.BalabanCMP89NeumannReflectionRepresentation (5.1s)
# ✔ [10521/10827] Built YangMills.RG.BalabanCMP89NeumannReflectionResidueDictionary (5.5s)
# ℹ [10522/10827] Built YangMills.RG.BalabanCMP89SourceNeumannRegionalPrecisionAudit (11s)
# info: YangMills/RG/BalabanCMP89SourceNeumannRegionalPrecisionAudit.lean:10:0: 'YangMills.RG.inner_cmp89SourceNeumannRegionalLaplacian' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89SourceNeumannRegionalPrecisionAudit.lean:11:0: 'YangMills.RG.cmp89SourceNeumannRegionalLaplacian_isSymmetric' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10523/10827] Built YangMills.RG.BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit (11s)
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit.lean:3:0: 'YangMills.RG.norm_cmp89Eq248ComplexAliasDenominatorSummand_sub_realSlice_le_sourceWeight' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249ComplexNoncentralAliasSumVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq249ComplexNoncentralAliasSum_sub_realSlice_le_bound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10524/10856] Built YangMills.RG.BalabanCMP89NeumannReflectionScaleDictionaryAudit (5.3s)
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:8:0: 'YangMills.RG.mem_cmp89SourceNeumannPrintedInclusiveIntegerRectangle_iff' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:9:0: 'YangMills.RG.mem_cmp89SourceNeumannBlockIntegerRectangle_iff' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:10:0: 'YangMills.RG.cmp89SourceNeumannBlockIntegerRectangle_zero_mem' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:11:0: 'YangMills.RG.cmp89SourceNeumannBlockIntegerRectangle_subset_printedInclusive' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:12:0: 'YangMills.RG.cmp89NeumannLeftReflection_spacing_dictionary' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:13:0: 'YangMills.RG.cmp89NeumannRightReflection_spacing_dictionary' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:14:0: 'YangMills.RG.cmp89NeumannRightReflection_physical_dictionary' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:15:0: 'YangMills.RG.cmp89NeumannLeftReflectionImage_spacing_dictionary' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionScaleDictionaryAudit.lean:16:0: 'YangMills.RG.cmp89NeumannRightReflectionImage_physical_dictionary' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10525/10857] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedDenominatorVariation (11s)
# ℹ [10526/10857] Built YangMills.RG.BalabanCMP89NeumannDirichletBoundaryNoGoAudit (12s)
# info: YangMills/RG/BalabanCMP89NeumannDirichletBoundaryNoGoAudit.lean:10:0: 'YangMills.RG.cmp89SourceNeumannRegionalCovariantD0CLM_boundary_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannDirichletBoundaryNoGoAudit.lean:11:0: 'YangMills.RG.cmp99ActiveRegionSourceCovariantD0CLM_boundary_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannDirichletBoundaryNoGoAudit.lean:12:0: 'YangMills.RG.cmp89SourceNeumannRegionalCovariantD0CLM_ne_dirichlet_of_boundary' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10527/10858] Built YangMills.RG.BalabanCMP89NeumannReflectionResidueDictionaryAudit (5.4s)
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:7:0: 'YangMills.RG.cmp89NeumannReflectionBaseResidue' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:8:0: 'YangMills.RG.cmp89NeumannReflectionPeriod' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:9:0: 'YangMills.RG.cmp89NeumannReflection_displacement_apply' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:10:0: 'YangMills.RG.cmp89NeumannReflection_displacement' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:11:0: 'YangMills.RG.cmp89NeumannReflectedCenteredMagnitude' does not depend on any axioms
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:12:0: 'YangMills.RG.cmp89Neumann_direct_natAbs_le_reflected_distances' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:13:0: 'YangMills.RG.cmp89Neumann_direct_natAbs_le_reflectedCenteredMagnitude' depends on axioms: [propext, Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionResidueDictionaryAudit.lean:14:0: 'YangMills.RG.cmp89Neumann_direct_natAbs_le_reflectedCenteredMagnitude_apply' depends on axioms: [propext, Quot.sound]
# ℹ [10528/10858] Built YangMills.RG.BalabanCMP89NeumannReflectionRepresentationAudit (5.0s)
# info: YangMills/RG/BalabanCMP89NeumannReflectionRepresentationAudit.lean:9:0: 'YangMills.RG.CMP89NeumannReflectionRepresentationCertificate.side_pos' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionRepresentationAudit.lean:10:0: 'YangMills.RG.CMP89NeumannReflectionRepresentationCertificate.summable' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionRepresentationAudit.lean:11:0: 'YangMills.RG.CMP89NeumannReflectionRepresentationCertificate.representation' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionRepresentationAudit.lean:12:0: 'YangMills.RG.CMP89NeumannReflectionRepresentationCertificate.carrier_nonempty' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89NeumannReflectionRepresentationAudit.lean:13:0: 'YangMills.RG.CMP89NeumannReflectionRepresentationCertificate.eq_series' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10529/10858] Built YangMills.RG.BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit (9.9s)
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:3:0: 'YangMills.RG.cmp99FlatComplexFibrePointSource' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:4:0: 'YangMills.RG.sum_cmp99FlatFourierMode_mul_inv' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:5:0: 'YangMills.RG.cmp99FlatComplexFibrePointSource_eq_normalized_sum_fourierMode' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99FlatComplexFibrePointSourceFourierReconstructionAudit.lean:6:0: 'YangMills.RG.ContinuousLinearMap_apply_cmp99FlatComplexFibrePointSource_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10530/10859] Built YangMills.RG.BalabanCMP85TypedGreenInverse (26s)
# ✔ [10531/10860] Built YangMills.RG.BalabanCMP89Eq251StabilizedEndpointCentralFineUpper (7.7s)
# ℹ [10532/10861] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit (10s)
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:3:0: 'YangMills.RG.cmp89Eq245EntireScaledLaplacianVerticalBudget_le_centralBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:4:0: 'YangMills.RG.norm_cmp89Eq249CentralEntireFineSymbol_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP89Eq249CentralStabilizedDenominatorVariationAudit.lean:5:0: 'YangMills.RG.norm_cmp89Eq249CentralStabilizedAliasDenominator_sub_realSlice_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [10533/10861] Built YangMills.RG.BalabanCMP89Eq249CentralStabilizedComplexFloor (7.8s)
# ℹ [10534/10862] Built YangMills.RG.BalabanCMP85BlockGaussianAlgebraAudit (6.9s)
# info: YangMills/RG/BalabanCMP85BlockGaussianAlgebraAudit.lean:12:0: 'YangMills.RG.cmp85_rightSchurBracket_eq_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP85BlockGaussianAlgebraAudit.lean:13:0: 'YangMills.RG.cmp85_leftSchurBracket_eq_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# ℹ [10535/10863] Built YangMills.RG.BalabanCMP99SourcePrefixPoincareAudit (14s)
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:7:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_le_succ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:8:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_monotone' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:9:0: 'YangMills.RG.cmp99SourcePoincareErrorCoeff_le_succ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:10:0: 'YangMills.RG.cmp99SourcePoincareErrorCoeff_monotone' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:11:0: 'YangMills.RG.cmp99SourcePoincareEnergyCoeff_pos' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:12:0: 'YangMills.RG.cmp99OneScaleBlockPoincareConstant_pow_pos' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:13:0: 'YangMills.RG.cmp99SourcePoincareErrorCoeff_lt_of_le_depth' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourcePrefixPoincareAudit.lean:14:0: 'YangMills.RG.cmp99SourceGeneratedRetainedPhysicalTower_prefix_poincare' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [10536/10863] Built YangMills.RG.BalabanCMP99SourceCanonicalPrefixTowerAudit (18s)
# info: YangMills/RG/BalabanCMP99SourceCanonicalPrefixTowerAudit.lean:8:0: 'YangMills.RG.CMP99SourceActiveRegionChain.take' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceCanonicalPrefixTowerAudit.lean:9:0: 'YangMills.RG.CMP99SourceActiveRegionChain.takeFin' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceCanonicalPrefixTowerAudit.lean:10:0: 'YangMills.RG.CMP99SourceActiveRegionChain.take_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceCanonicalPrefixTowerAudit.lean:11:0: 'YangMills.RG.CMP99SourceActiveRegionChain.take_step_succ' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99SourceCanonicalPrefixTowerAudit.lean:12:0: 'YangMills.RG.CMP99SourceUbarRadiusChain.take' depends on axioms: [propext, Classical.choice, Quot.sound]
# ...
#  Classical.choice,
#  Quot.sound]
# ✔ [11151/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecay (16s)
# ✔ [11152/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedPhysicalLaplacianDictionary (18s)
# ℹ [11153/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedPhysicalPrecisionDictionaryAudit (11s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedPhysicalPrecisionDictionaryAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedDirichletPrecision_eq_reindexed_sourceGaugePrecision' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11154/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputActionZeroDepth (11s)
# ℹ [11155/11185] Built YangMills.RG.BalabanCMP99Eq360C6dCanonicalAmbientCompletionAudit (15s)
# info: YangMills/RG/BalabanCMP99Eq360C6dCanonicalAmbientCompletionAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedCanonicalAmbientCompletion_green_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dCanonicalAmbientCompletionAudit.lean:6:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedCanonicalAmbientCompletion_green_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11156/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputAction (12s)
# ℹ [11157/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit (51s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedZeroDepthCoercivity' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecision_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:5:0: 'YangMills.RG.isCoerciveCLM_cmp99Eq360C6dSourceSeparatedAmbientPrecision_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:6:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedDirichletPrecision_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:7:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedRegionalDirichletPrecision_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:8:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:9:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedRegionalDirichletGreen_eq_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:10:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedDirichletPrecision_comp_green_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:11:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_comp_precision_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthAudit.lean:12:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11158/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedPhysicalLaplacianDictionaryAudit (11s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedPhysicalLaplacianDictionaryAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedPhysicalBondEquiv' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedPhysicalLaplacianDictionaryAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedCovariantD0_reindex_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedPhysicalLaplacianDictionaryAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedCovariantLaplacian_reindex_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11159/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayZeroDepthAudit (19s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayZeroDepthAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecisionDecayAmplitude_zero' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayZeroDepthAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecision_zero_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayZeroDepthAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11160/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecayZeroDepth (10s)
# ℹ [11161/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputActionZeroDepthAudit (9.6s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputActionZeroDepthAudit.lean:3:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_apply_le_sourceScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11162/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputActionAudit (9.8s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerInputActionAudit.lean:3:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_apply_le_sourceScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11163/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecay (11s)
# ℹ [11164/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayAudit (22s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecisionDecayAmplitude' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceAmbientBaselinePrecision_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecision_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenDecayAudit.lean:6:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_exponentialKernelBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11165/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecayZeroDepth (9.8s)
# ℹ [11166/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecayZeroDepthAudit (10s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecayZeroDepthAudit.lean:3:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_apply_le_ownerScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11167/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecayAudit (10s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenOwnerDecayAudit.lean:3:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_apply_le_ownerScale' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11168/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecay (10s)
# ℹ [11169/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecayZeroDepthAudit (11s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecayZeroDepthAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11170/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthActions (12s)
# ℹ [11171/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit (60s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientSiteEquiv' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientRegion' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientRegion_symm_eq' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:6:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedC6dAmbientPrecision' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:7:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecision' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:8:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedRegionalDirichletPrecision_eq_ambient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:9:0: 'YangMills.RG.isCoerciveCLM_cmp99Eq360C6dSourceSeparatedAmbientPrecision' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:10:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedDirichletPrecision_eq_pullback' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:11:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:12:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedRegionalDirichletGreen_eq_ambient' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:13:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientPrecision_comp_green' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:14:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_comp_precision' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:15:0: 'YangMills.RG.norm_cmp99Eq360C6dSourceSeparatedAmbientGreen_le' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:16:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedPulledBackC6dGreen' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenAudit.lean:17:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_eq_pullback' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11172/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLeftDerivative (12s)
# ℹ [11173/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecayAudit (13s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenBlockLocalizedOwnerDecayAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11174/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenRightAdjoint (14s)
# ℹ [11175/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLeftDerivativeAudit (15s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLeftDerivativeAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_leftDerivative_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11176/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLaplacian (15s)
# ℹ [11177/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenRightAdjointAudit (15s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenRightAdjointAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_rightAdjoint_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11178/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthCertificate (22s)
# ℹ [11179/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthActionsAudit (23s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthActionsAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_leftDerivative_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthActionsAudit.lean:4:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_rightAdjoint_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthActionsAudit.lean:5:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zero_laplacian_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11180/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLaplacianAudit (7.6s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenLaplacianAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_laplacian_blockLocalizedSupBound' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ℹ [11181/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthCertificateAudit (7.2s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenZeroDepthCertificateAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_zeroDepthCertificate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11182/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenPerDepthCertificate (13s)
# ℹ [11183/11185] Built YangMills.RG.BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenPerDepthCertificateAudit (6.8s)
# info: YangMills/RG/BalabanCMP99Eq360C6dSourceSeparatedAmbientGreenPerDepthCertificateAudit.lean:3:0: 'YangMills.RG.cmp99Eq360C6dSourceSeparatedAmbientGreen_perDepthCertificate' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# ✔ [11184/11185] Built YangMillsCore (5.3s)
# Build completed successfully (11185 jobs).
#
# STAGE=cmp89_neumann_dirichlet_boundary_nogo_root EXIT=0 SECONDS=6704.031
# EVIDENCE_SHA256=a7caeead64ce2e13137341fcee3d153d3c78bbfd4109537ab12eee8f6b23ac34
# EVIDENCE_ARCHIVE=/content/hrpoly-cmp89-neumann-dirichlet-boundary-nogo-evidence.tar.gz
# EVIDENCE_ARCHIVE_SHA256=bab070fcfc2a6c5ae4e5acac72e4e2de68f1e6d21c4f84ae30d586be0926198c
# FINAL_STATUS=PASS
# RUNTIME_UNASSIGN_DEFERRED_TO_LAUNCHER=1
# RUNTIME_UNASSIGN_REQUESTED=1
# EVIDENCE_DOWNLOAD_REQUESTED=1
# LAUNCHER_EXIT=0
