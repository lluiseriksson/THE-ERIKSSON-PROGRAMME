# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/ae829ac4353f3a058daab3317c3407f689ee13cd/scripts/colab_c6d_source_separated_ambient_green_validation.py"
RUNNER_SHA256 = "f003e2077a5d6e0f60b392b7cee845ca38c920ba0dd01009d3f8ee70dba913b4"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
release_runtime = runtime.unassign
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    if launcher_exit == 0:
        print("RUNTIME_RETAINED_FOR_EVIDENCE_DOWNLOAD=1", flush=True)
    else:
        print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
# info: YangMills/RG/BalabanCMP116LocalizedCovarianceCompressionAudit.lean:18:0: 'YangMills.RG.cmp116Eq223CoordinateProjection_transpose' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116LocalizedCovarianceCompressionAudit.lean:19:0: 'YangMills.RG.norm_cmp116Eq223CoordinateProjection_le_one' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116LocalizedCovarianceCompressionAudit.lean:20:0: 'YangMills.RG.norm_cmp116LocalizedCovarianceCompression_le' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP116LocalizedCovarianceCompressionAudit.lean:21:0: 'YangMills.RG.cmp116LocalizedCovarianceCompression_supported' depends on axioms: [propext, Classical.choice, Quot.sound]
# ...
