# %%
import hashlib, urllib.request
from google.colab import runtime
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/e55d9cf4a4886f31ab4a60d8598a575994cf8cbd/scripts/colab_c6d_ambient_compression_cold_validation.py"
RUNNER_SHA256 = "f398be1a48349b237fde7f90cec45bcb0d369fb80ffaf213922206e57a9f3553"
with urllib.request.urlopen(RUNNER_URL) as response:
    runner_source = response.read()
measured = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + measured, flush=True)
if measured != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
runtime.unassign = lambda: print("RUNTIME_UNASSIGN_DEFERRED=1", flush=True)
launcher_exit = 0
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), {"__name__": "__main__"})
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
except BaseException as exc:
    launcher_exit = 1
    print("LAUNCHER_EXCEPTION=" + repr(exc), flush=True)
finally:
    print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
    if launcher_exit == 0:
        print("RUNTIME_RETAINED_FOR_EVIDENCE_DOWNLOAD=1", flush=True)
    else:
        print("RUNTIME_RETAINED_FOR_DEBUG=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
#  Classical.choice,
#  Quot.sound]
# ℹ [10329/10389] Built YangMills.RG.BalabanCMP102AmbientExpAverageThirdJetBoundAudit (19s)
# info: YangMills/RG/BalabanCMP102AmbientExpAverageThirdJetBoundAudit.lean:3:0: 'YangMills.RG.cmp102SourceLogAverageNNRadius' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientExpAverageThirdJetBoundAudit.lean:4:0: 'YangMills.RG.cmp102SourceExpOrderThreeOuterBudget' depends on axioms: [propext, Classical.choice, Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientExpAverageThirdJetBoundAudit.lean:5:0: 'YangMills.RG.norm_iteratedFDeriv_exp_le_orderThreeOuterBudget' depends on axioms: [propext,
#  Classical.choice,
#  Quot.sound]
# info: YangMills/RG/BalabanCMP102AmbientExpAverageThirdJetBoundAudit.lean:6:0: 'YangMills.RG.cmp102SourceLogAverageCompositionRadius' depends on axioms: [propext, Classical.choice, Quot.sound]
# ...
