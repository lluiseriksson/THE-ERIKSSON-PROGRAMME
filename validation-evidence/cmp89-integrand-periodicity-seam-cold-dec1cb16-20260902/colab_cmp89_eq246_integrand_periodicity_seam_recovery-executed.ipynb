# %%
import hashlib, urllib.request
RUNNER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/2cdc9b070b6b28f098f81c2bd0a36d5e6d3915bd/scripts/colab_cmp89_eq246_solution_cycle_validation.py"
RUNNER_SHA256 = "d85829f77f3b8b8fb550270453dcb3ec7be86ceeda9e7b73571ddfd47e51ecc2"
with urllib.request.urlopen(RUNNER_URL, timeout=60) as response:
    runner_source = response.read()
runner_hash = hashlib.sha256(runner_source).hexdigest()
print("RUNNER_TRANSPORT_SHA256=" + runner_hash, flush=True)
if runner_hash != RUNNER_SHA256:
    raise RuntimeError("RUNNER_TRANSPORT_HASH_MISMATCH")
launcher_exit = 0
runner_namespace = {"__name__": "__main__"}
try:
    exec(compile(runner_source, RUNNER_URL, "exec"), runner_namespace)
except SystemExit as exc:
    launcher_exit = int(exc.code or 0)
runner_module = runner_namespace.get("runner")
archive = getattr(runner_module, "ARCHIVE", None)
if archive is not None and archive.is_file():
    archive_hash = hashlib.sha256(archive.read_bytes()).hexdigest()
    print("LAUNCHER_EVIDENCE_ARCHIVE=" + str(archive), flush=True)
    print("LAUNCHER_EVIDENCE_ARCHIVE_SHA256=" + archive_hash, flush=True)
print(f"LAUNCHER_EXIT={launcher_exit}", flush=True)
print("LAUNCHER_RUNTIME_RETAINED=1", flush=True)
if launcher_exit != 0:
    raise RuntimeError(f"RUNNER_EXIT={launcher_exit}")

# %%
from pathlib import Path
import hashlib, json, os
root = Path("/content/hrpoly-cmp89-eq246-integrand-periodicity-seam-cold-v1")
evidence = Path("/content/hrpoly-cmp89-eq246-integrand-periodicity-seam-cold-v1-evidence/evidence.json")
archive = Path("/content/hrpoly-cmp89-eq246-integrand-periodicity-seam-cold-v1-evidence.tar.gz")
print("HELPER_READ_ONLY=1", flush=True)
print("ROOT_EXISTS=" + str(root.exists()), flush=True)
print("EVIDENCE_EXISTS=" + str(evidence.is_file()), flush=True)
print("ARCHIVE_EXISTS=" + str(archive.is_file()), flush=True)
if evidence.is_file():
    raw = evidence.read_bytes()
    payload = json.loads(raw)
    print("FINAL_STATUS=" + str(payload.get("status")), flush=True)
    print("EVIDENCE_JSON_SHA256=" + hashlib.sha256(raw).hexdigest().upper(), flush=True)
    print("RUNNER_REV=" + str(payload.get("runner_rev")), flush=True)
    print("SOURCE_SHA=" + str(payload.get("source_sha")), flush=True)
    for rec in payload.get("records", []):
        print("RECORD=" + str(rec.get("stage")) + " EXIT=" + str(rec.get("exit")) + " SECONDS=" + str(rec.get("seconds")), flush=True)
    print("AXIOM_BLOCKS=" + str(payload.get("axiom_blocks")), flush=True)
if archive.is_file():
    print("ARCHIVE_SHA256=" + hashlib.sha256(archive.read_bytes()).hexdigest().upper(), flush=True)
# Out:
# HELPER_READ_ONLY=1
# ROOT_EXISTS=True
# EVIDENCE_EXISTS=True
# ARCHIVE_EXISTS=True
# FINAL_STATUS=PASS
# EVIDENCE_JSON_SHA256=51AAB3A1C51923212D1D64CE00298E4A979C93344F7116733FC47BBBA65347D7
# RUNNER_REV=cmp89-eq246-integrand-periodicity-seam-cold-v1
# SOURCE_SHA=dec1cb163d7d0d2dd5d79270f6591db68a17ec5f
# RECORD=download_toolchain EXIT=0 SECONDS=2.5085183979999783
# RECORD=extract_toolchain EXIT=0 SECONDS=14.041988324000158
# RECORD=lean_version EXIT=0 SECONDS=0.06730732000005446
# RECORD=lake_version EXIT=0 SECONDS=0.06796775700013313
# RECORD=clone EXIT=0 SECONDS=18.279116434000116
# RECORD=checkout EXIT=0 SECONDS=2.3513045150002654
# RECORD=head EXIT=0 SECONDS=0.006297136000284809
# RECORD=overlay_text_guard EXIT=0 SECONDS=0.1578420549999464
# RECORD=import_prefix_guard EXIT=0 SECONDS=0.06998844200006715
# RECORD=lake_update EXIT=0 SECONDS=133.63451497699998
# RECORD=mathlib_pin EXIT=0 SECONDS=0.0034325340002396842
# RECORD=cache_get EXIT=0 SECONDS=6.193796765000116
# ...

# %%
from google.colab import files
files.download("/content/hrpoly-cmp89-eq246-integrand-periodicity-seam-cold-v1-evidence.tar.gz")
