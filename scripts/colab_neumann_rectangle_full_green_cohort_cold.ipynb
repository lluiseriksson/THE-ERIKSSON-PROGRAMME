# %% [markdown]
# # Rectangle + actual full-G — eight-name cold cohort
# CPU/high RAM, no GPU. Fresh clone, no project outputs restored. Not inverse/B0/window15. 20/41 unchanged.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime
SOURCE_SHA = "d9d1bcae8e53b2ad442f507de0d695a1c5e0ccd6"
RUNNER_REV = "neumann-rectangle-full-green-cohort-cold-v1"
LAUNCHER_SHA256 = "76c9b77cf2669e9d8cff741b5e012c674854298046ea9a2eb2cb2a369898112e"
url = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/ad37ffab980280db38c3819742c5828217cebfdf/scripts/launch_neumann_rectangle_full_green_cohort_cold.py"
launcher = pathlib.Path("/content/launch-neumann-rectangle-full-green-cold-v1.py")
log = pathlib.Path("/content/launch-neumann-rectangle-full-green-cold-v1-console.log")
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == LAUNCHER_SHA256, "TRANSPORT_HASH"
launcher.write_bytes(blob)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with log.open("xb") as stream:
    proc = subprocess.Popen([sys.executable, str(launcher)], stdout=stream, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(proc.pid), flush=True)
    code = proc.wait()
print(log.read_text(errors="replace")[-18000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
from google.colab import files
archive = pathlib.Path("/content/neumann-rectangle-full-green-cohort-cold-v1-preservation-20260906.tar.gz")
if archive.is_file():
    files.download(str(archive))
if code:
    raise RuntimeError("Cold gate stopped. Preserve the first error; do not rerun.")
