# %% [markdown]
# # Canonical Neumann precision — two-name cold gate
# Fresh CPU/high-RAM clone. No project build outputs restored. Finite action only, not Fourier normalization, regional inverse, uniform B0 or window15; 20/41 unchanged.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "4746880218c694a9d4e9d32c0af61f86d460b7b4"
RUNNER_REV = "neumann-canonical-precision-promoted-cold-v1"
LAUNCHER_SHA256 = "a43bc5b5829942afebcfa09e9be181df79b59bf41aa1948b1fdff40ebc6ef68f"
url = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/8ed60e286f2d670acfd0662ca21541fbedf20c29/scripts/launch_neumann_canonical_precision_promoted_cold.py"
launcher = pathlib.Path("/content/launch-neumann-canonical-precision-cold-v1.py")
log = pathlib.Path("/content/launch-neumann-canonical-precision-cold-v1-console.log")
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == LAUNCHER_SHA256, "TRANSPORT_HASH"
launcher.write_bytes(blob)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with log.open("xb") as stream:
    proc = subprocess.Popen([sys.executable, str(launcher)], stdout=stream, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(proc.pid), flush=True)
    code = proc.wait()
print(log.read_text(errors="replace")[-18000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
from google.colab import files
archive = pathlib.Path("/content/neumann-canonical-precision-promoted-cold-v1-preservation-20260906.tar.gz")
if archive.is_file():
    files.download(str(archive))
if code:
    raise RuntimeError("Cold gate stopped. Preserve the first error; do not rerun.")
