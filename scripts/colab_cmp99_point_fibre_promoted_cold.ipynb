# %% [markdown]
# # F5 promoted point/fibre — cold gate
# CPU/high RAM, no GPU. One execution only. No project cache restoration.
# Seven audit declarations. Not regional B0, window15 or a terminal inhabitant.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime
SOURCE_SHA = "6c49a8daeb6d6c6f60ac4a2cd2bafda67a495ff4"
RUNNER_REV = "cmp99-point-fibre-promoted-cold-v1"
LAUNCHER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/beb1d1e00ad3fdc894d0705883e66765df558ae9/scripts/launch_cmp99_point_fibre_promoted_cold.py"
LAUNCHER_SHA256 = "d0424a920099ec2c30822b04392c9b6ad8e5a339cba80597cab1bfeffe7342b8"
launcher = pathlib.Path("/content/launch_f5_promoted_cold.py")
assert not launcher.exists(), "ALREADY_STARTED_NO_REEXECUTION"
with urllib.request.urlopen(LAUNCHER_URL, timeout=60) as response:
    payload = response.read()
assert hashlib.sha256(payload).hexdigest() == LAUNCHER_SHA256, "LAUNCHER_HASH_MISMATCH"
launcher.write_bytes(payload)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with open("/content/f5-promoted-cold-console.log", "xb") as log:
    child = subprocess.Popen([sys.executable, "-u", str(launcher)], stdout=log, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(child.pid), flush=True)
    code = child.wait()
pathlib.Path("/content/f5-promoted-cold-exit.txt").write_text(str(code) + "\n")
print(pathlib.Path("/content/f5-promoted-cold-console.log").read_text(errors="replace")[-12000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
if code:
    raise RuntimeError("Cold gate stopped: inspect preserved first error; do not reexecute")
