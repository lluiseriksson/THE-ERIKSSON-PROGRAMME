# %% [markdown]
# # Physical readout integral — cold gate
# Source 3391796fbcd65fa8f4453f5e482b36bc19f455c6; five audited names. One fresh checkout, no project build restoration. Not physical operator interchange or window 15.

# %%
import pathlib, hashlib, urllib.request, subprocess, sys, datetime
RUNNER_REV = 'physical-readout-integral-cold-launch-v1'
launch = pathlib.Path('/content/' + RUNNER_REV)
assert not launch.exists(), 'NO_REEXECUTION'
import psutil
assert psutil.virtual_memory().total / 2**30 >= 40, 'HIGH_RAM_REQUIRED'
launch.mkdir()
url = 'https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/3b1e06a6328badf5af5b92126daead11dc255c20/scripts/colab_neumann_physical_readout_integral_promoted_cold.py'
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == '5ee8ae72415faf1e4977dfcc716ad05e3ef878e49b7c97ac9e623872097f8ba9', 'RUNNER_HASH'
path = launch / 'runner.py'
path.write_bytes(blob)
log = open(launch / 'launch.log', 'w')
child = subprocess.Popen([sys.executable, str(path)], stdout=log, stderr=subprocess.STDOUT)
log.close()
(launch / 'pid.txt').write_text(str(child.pid))
print('OPENED_UTC=' + datetime.datetime.now(datetime.timezone.utc).isoformat())
print('CPU_HIGH_RAM_GIB=' + str(psutil.virtual_memory().total / 2**30))
print('RUNNER_HASH_PASS PID=' + str(child.pid))
