# %% [markdown]
# # Counting reflection and retained terminal mass — promoted cold gate
# CPU/high RAM, no GPU. One execution at raw source 9b73a5fe3, four hash-pinned files, five named axioms, two production outputs. No project output restoration. Not arbitrary regional invariance, Neumann inverse or window15. Counters20/41 and TermSource0 unchanged.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "9b73a5fe37d1e5e3c8589af211c46708a9d0a7bb"
RUNNER_REV = "neumann-counting-promoted-cold-v1"
LAUNCHER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/b8f85c9dc28920f5c0b0552f1c8a45a86baa0e62/scripts/launch_neumann_counting_promoted_cold.py"
LAUNCHER_SHA256 = "6f124ac7c43e7f3fa247123db0420b2c903c7e9161ac6a06fcf670d3ef5d69d9"
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
launcher = pathlib.Path("/content/launch_neumann_counting_promoted_cold_v1.py")
log = pathlib.Path("/content/neumann-counting-promoted-cold-v1-console.log")
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
with urllib.request.urlopen(LAUNCHER_URL, timeout=60) as response:
    payload = response.read()
assert hashlib.sha256(payload).hexdigest() == LAUNCHER_SHA256, "LAUNCHER_HASH_MISMATCH"
launcher.write_bytes(payload)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat() + " RUNTIME=CPU RAM_GIB=" + str(psutil.virtual_memory().total / 2**30), flush=True)
with log.open("xb") as out:
    child = subprocess.Popen([sys.executable, "-u", str(launcher)], stdout=out, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(child.pid), flush=True)
    code = child.wait()
pathlib.Path("/content/neumann-counting-promoted-cold-v1-exit.txt").write_text(str(code) + "\n")
print(log.read_text(errors="replace")[-12000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
from google.colab import files
files.download("/content/neumann-counting-promoted-cold-v1-preservation-20260906.tar.gz")
if code:
    raise RuntimeError("Cold gate stopped; preserve first error; do not reexecute")
