# %% [markdown]
# # Neumann internal-bond stencil — four-name cold gate
# Fresh CPU/high-RAM clone. No project build outputs restored. Actual internal-bond adjoint/divergence only, not reflected Green boundary law, regional inverse, uniform B0 or window15; 20/41 unchanged.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "81f35765ad50f8217bca20bc4530d99b3bf05103"
RUNNER_REV = "neumann-internal-bond-stencil-promoted-cold-v1"
LAUNCHER_SHA256 = "d7620dfeb9545a659e35f1b2390fcc9967fe12600ef8613b0998ec7ee3a405e6"
url = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/8111de7b896885565fdc6327e5c039b5acb7985e/scripts/launch_neumann_internal_bond_stencil_promoted_cold.py"
launcher = pathlib.Path("/content/launch-neumann-internal-bond-stencil-cold-v1.py")
log = pathlib.Path("/content/launch-neumann-internal-bond-stencil-cold-v1-console.log")
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == LAUNCHER_SHA256, "TRANSPORT_HASH"
launcher.write_bytes(blob)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with log.open("xb") as stream:
    proc = subprocess.Popen([sys.executable, str(launcher)], stdout=stream, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(proc.pid), flush=True)
    code = proc.wait()
print(log.read_text(errors="replace")[-18000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
from google.colab import files
archive = pathlib.Path("/content/neumann-internal-bond-stencil-promoted-cold-v1-preservation-20260906.tar.gz")
if archive.is_file():
    files.download(str(archive))
if code:
    raise RuntimeError("Cold gate stopped. Preserve the first error; do not rerun.")
