# %% [markdown]
# # Physical Green-owner-point prefix — nine-name cold gate
# CPU/high RAM, no GPU. Exactly one execution; no exploratory CI.
# Fresh clone → three focal/audit pairs, nine exact declarations. Intermediate seal only;20/41 unchanged.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "b2d5df8ad6d600317b267bf87522a8bf472e9ea0"
RUNNER_REV = "cmp99-physical-prefix-promoted-cold-v1"
LAUNCHER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/c288fcd9f6c01895a2d651d1a06979db9804de3d/scripts/launch_cmp99_physical_prefix_promoted_cold.py"
LAUNCHER_SHA256 = "ea651b87ce97f47dce9ffc0df926ce5c13474852148425e896cdd36894bd9ecc"
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
launcher = pathlib.Path("/content/launch_physical_prefix_promoted_cold_v1.py")
assert not launcher.exists(), "ALREADY_STARTED_NO_REEXECUTION"
with urllib.request.urlopen(LAUNCHER_URL, timeout=60) as response:
    payload = response.read()
assert hashlib.sha256(payload).hexdigest() == LAUNCHER_SHA256, "LAUNCHER_HASH_MISMATCH"
launcher.write_bytes(payload)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with open("/content/physical-prefix-promoted-cold-v1-console.log", "xb") as log:
    child = subprocess.Popen([sys.executable, "-u", str(launcher)], stdout=log, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(child.pid), flush=True)
    code = child.wait()
pathlib.Path("/content/physical-prefix-promoted-cold-v1-exit.txt").write_text(str(code) + "\n")
print(pathlib.Path("/content/physical-prefix-promoted-cold-v1-console.log").read_text(errors="replace")[-12000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
if code:
    raise RuntimeError("Cold gate stopped: preserve first error; do not reexecute")
