# %% [markdown]
# # Physical ambient value action — three-name cold gate
# CPU/high RAM, no GPU. Run this single cell once. Fresh source10437a1a8; no project output restoration. Focal and exact three-name audit. Intermediate only:20/41,TermSource0,window15unattained.
# Evidence must be downloaded and independently verified before selective seal. The previous completed runtime was deleted; never reuse or rerun its notebook.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "10437a1a824bdd920282778cabe2f3da6c40ce4e"
RUNNER_REV = "cmp99-physical-value-action-promoted-cold-v1"
LAUNCHER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/b03e923c3c7363ea56f5b77485d76de4776c671d/scripts/launch_cmp99_physical_value_action_promoted_cold.py"
LAUNCHER_SHA256 = "b950a5acceac463d6e65d1cbd674fa4b05ab0b95c5f62556a72ec61c4ed292df"
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
launcher = pathlib.Path("/content/launch_physical_value_action_promoted_cold_v1.py")
log = pathlib.Path("/content/physical-value-action-promoted-cold-v1-console.log")
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
with urllib.request.urlopen(LAUNCHER_URL, timeout=60) as response:
    payload = response.read()
assert hashlib.sha256(payload).hexdigest() == LAUNCHER_SHA256, "LAUNCHER_HASH_MISMATCH"
launcher.write_bytes(payload)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with log.open("xb") as out:
    child = subprocess.Popen([sys.executable, "-u", str(launcher)], stdout=out, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(child.pid), flush=True)
    code = child.wait()
pathlib.Path("/content/physical-value-action-promoted-cold-v1-exit.txt").write_text(str(code) + "\n")
print(log.read_text(errors="replace")[-12000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
if code:
    raise RuntimeError("Cold gate stopped; preserve first error; do not reexecute")
from google.colab import files
files.download("/content/physical-value-action-promoted-cold-v1-preservation-20260905.tar.gz")
