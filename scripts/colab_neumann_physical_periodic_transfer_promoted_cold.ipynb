# %% [markdown]
# # Periodic physical transfer — PRE-VALIDATION cold gate
# One launch only. CPU/high RAM. Source 24dc691e451ab9b6684f950a3fdd5a78e913997f. No project cache restoration; no window15 or counter claim.

# %%
import pathlib, hashlib, urllib.request, subprocess, sys, datetime
RUNNER_REV = 'periodic-transfer-promoted-cold-launch-v1'
launch = pathlib.Path('/content/' + RUNNER_REV)
assert not launch.exists(), 'NO_REEXECUTION'
import psutil
assert psutil.virtual_memory().total / 2**30 >= 40, 'HIGH_RAM_REQUIRED'
launch.mkdir()
url = 'https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/83a45bd59e26f9f1d8ef2deb5e8b26234deed443/scripts/colab_neumann_physical_periodic_transfer_promoted_cold.py'
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == '933cfb2de560c40cd422c3b0628c6b0b8a73429655eddbe1e5f05546ff8dc340', 'RUNNER_HASH'
path = launch / 'runner.py'
path.write_bytes(blob)
log = (launch / 'launch.log').open('xb')
p = subprocess.Popen([sys.executable, '-u', str(path)], stdout=log, stderr=subprocess.STDOUT, start_new_session=True)
log.close()
print('OPENED_UTC=' + datetime.datetime.now(datetime.timezone.utc).isoformat())
print('CPU_HIGH_RAM_GIB=' + str(psutil.virtual_memory().total / 2**30))
print('RUNNER_HASH_PASS PID=' + str(p.pid))

# %%
import pathlib, json, psutil
launch = pathlib.Path('/content/periodic-transfer-promoted-cold-launch-v1')
print((launch/'launch.log').read_text(errors='replace')[-5000:])
