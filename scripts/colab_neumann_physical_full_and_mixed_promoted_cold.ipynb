# %% [markdown]
# # Physical FULL flag and mixed summability — promoted cold gate
# One launch; CPU/high RAM; no project build cache. Source 46bf719be34e586e83790fa1b2ff2092735faa12. Two production modules, eight named audits. No operator interchange, inverse, uniform B0 or window15 claim.

# %%
import pathlib, hashlib, urllib.request, subprocess, sys, datetime
RUNNER_REV = 'physical-full-and-mixed-cold-launch-v1'
launch = pathlib.Path('/content/' + RUNNER_REV)
assert not launch.exists(), 'NO_REEXECUTION'
import psutil
assert psutil.virtual_memory().total / 2**30 >= 40, 'HIGH_RAM_REQUIRED'
launch.mkdir()
url = 'https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/79f870c87e331daa9d5c4dd67a30b30eed11a184/scripts/colab_neumann_physical_full_and_mixed_promoted_cold.py'
blob = urllib.request.urlopen(url, timeout=60).read()
assert hashlib.sha256(blob).hexdigest() == 'b3bc26a55607f1c44886f4c6d159dcb474797c88f6c1d508fe7004561bd483b8', 'RUNNER_HASH'
path = launch / 'runner.py'
path.write_bytes(blob)
log = (launch / 'launch.log').open('xb')
p = subprocess.Popen([sys.executable, '-u', str(path)], stdout=log, stderr=subprocess.STDOUT, start_new_session=True)
(launch / 'pid.txt').write_text(str(p.pid))
log.close()
print('OPENED_UTC=' + datetime.datetime.now(datetime.timezone.utc).isoformat())
print('CPU_HIGH_RAM_GIB=' + str(psutil.virtual_memory().total / 2**30))
print('RUNNER_HASH_PASS PID=' + str(p.pid))

# %%
import pathlib, psutil
launch = pathlib.Path('/content/physical-full-and-mixed-cold-launch-v1')
pid = int((launch/'pid.txt').read_text())
print('PID='+str(pid)+' LIVE='+str(psutil.pid_exists(pid)))
print((launch/'launch.log').read_text(errors='replace')[-5000:])
