# %% [markdown]
# # Selector and opposite difference — promoted cold gate
# One launch, CPU/high RAM. Source1885a6c0886e595f0d3013c6ac2b9a71f3c93036. Five exact names, two outputs; no project build restoration. Not an actual physical source equation, inverse or window15.

# %%
import pathlib, hashlib, urllib.request, subprocess, sys, datetime
RUNNER_REV = 'selector-opposite-cold-launch-v1'
launch = pathlib.Path('/content/' + RUNNER_REV)
assert not launch.exists(), 'NO_REEXECUTION'
import psutil
assert psutil.virtual_memory().total / 2**30 >= 40, 'HIGH_RAM_REQUIRED'
launch.mkdir()
url = 'https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/c90e9d1e0da604ece9be893b24c7f1393c528cb1/scripts/colab_neumann_selector_opposite_promoted_cold.py'
blob = urllib.request.urlopen(url).read()
assert hashlib.sha256(blob).hexdigest() == 'e7cffe850560794e7a043b3c77e55524a65ff0532afac5a5433fc645d30a7dbc', 'RUNNER_HASH'
path = launch / 'runner.py'
path.write_bytes(blob)
log = open(launch / 'launch.log', 'w')
child = subprocess.Popen([sys.executable, str(path)], stdout=log, stderr=subprocess.STDOUT)
log.close()
(launch / 'pid.txt').write_text(str(child.pid))
print('OPENED_UTC=' + datetime.datetime.now(datetime.timezone.utc).isoformat())
print('CPU_HIGH_RAM_GIB=' + str(psutil.virtual_memory().total / 2**30))
print('RUNNER_HASH_PASS PID=' + str(child.pid))

# %%
import pathlib, psutil, time
launch = pathlib.Path('/content/selector-opposite-cold-launch-v1')
pid = int((launch / 'pid.txt').read_text())
print('PID', pid, 'STATUS', psutil.Process(pid).status() if psutil.pid_exists(pid) else 'MISSING')
if psutil.pid_exists(pid):
 for c in psutil.Process(pid).children(recursive=True):
  print(c.pid,c.status(),round(time.time()-c.create_time()),c.cmdline()[:3])
s = (launch/'launch.log').read_text(errors='replace')
print('\n'.join(l for l in s.splitlines() if l.startswith(('STAGE=','FINAL_STATUS=','EVIDENCE_','AXIOM_GATE=')))[-5000:])
if 'FINAL_STATUS=' in s: print(s[-3000:])
