# %% [markdown]
# # Integer image-owner — exact seven-name cold gate
# CPU/high RAM, no GPU. One execution, fresh SOURCE87edca651, no project output restoration. Integer image algebra only; no physical Q intertwiner or regional inverse. 20/41 unchanged. Preserve and independently verify evidence before selective seal and runtime deletion.

# %%
import hashlib, pathlib, subprocess, sys, urllib.request, datetime, psutil
SOURCE_SHA = "87edca6519df5b450b906e83db2ffa4fc1bd87bd"
RUNNER_REV = "neumann-integer-image-promoted-cold-v1"
LAUNCHER_URL = "https://raw.githubusercontent.com/lluiseriksson/THE-ERIKSSON-PROGRAMME/7d73d5a57aba341f4f54bc0a8797ae33cf699760/scripts/launch_neumann_integer_image_promoted_cold.py"
LAUNCHER_SHA256 = "0026a86bb1db3a7dea2d0166375c9b0b58eda4bb9160bd58378020fe4e54d162"
assert psutil.virtual_memory().total / 2**30 >= 40, "HIGH_RAM_REQUIRED"
assert not pathlib.Path("/dev/nvidia0").exists(), "GPU_NOT_AUTHORIZED"
launcher = pathlib.Path("/content/launch_neumann_integer_image_promoted_cold_v1.py")
log = pathlib.Path("/content/neumann-integer-image-promoted-cold-v1-console.log")
assert not launcher.exists() and not log.exists(), "ALREADY_STARTED_NO_REEXECUTION"
with urllib.request.urlopen(LAUNCHER_URL, timeout=60) as response:
    payload = response.read()
assert hashlib.sha256(payload).hexdigest() == LAUNCHER_SHA256, "LAUNCHER_HASH_MISMATCH"
launcher.write_bytes(payload)
print("SOURCE_SHA=" + SOURCE_SHA + " RUNNER_REV=" + RUNNER_REV, flush=True)
print("HASH_GATE=PASS START_UTC=" + datetime.datetime.now(datetime.timezone.utc).isoformat(), flush=True)
with log.open("xb") as out:
    child = subprocess.Popen([sys.executable, "-u", str(launcher)], stdout=out, stderr=subprocess.STDOUT)
    print("LAUNCH_PID=" + str(child.pid), flush=True)
    code = child.wait()
pathlib.Path("/content/neumann-integer-image-promoted-cold-v1-exit.txt").write_text(str(code) + "\n")
print(log.read_text(errors="replace")[-12000:], flush=True)
print("LAUNCHER_EXIT=" + str(code), flush=True)
from google.colab import files
files.download("/content/neumann-integer-image-promoted-cold-v1-preservation-20260906.tar.gz")
if code:
    raise RuntimeError("Cold gate stopped; preserve first error; do not reexecute")
